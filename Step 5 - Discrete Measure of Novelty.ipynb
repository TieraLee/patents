# %%
import pandas as pd
import numpy as np

# %%
#import relevant data
master = pd.read_csv('data/master.csv')
citations = pd.read_csv('data/citations.csv', dtype={'patent_number':str})
focal_citation_link = pd.read_csv('data/citations_patents_level.csv')
focal_class = pd.read_csv('data/uspcs_level.csv')

# %%
master.head()
# Out:
#   patent_number  grant_year  app_year  num_inventors  us_inventor  \
# 0       D257752        1981      1980              1          1.0
# 1       D257924        1981      1980              1          1.0
# 2       D258382        1981      1980              2          1.0
# 3       D258383        1981      1980              2          1.0
# 4       D258571        1981      1980              1          1.0
#
#    cite_foreign_patent  is_missing  num_design_cited  num_utility_cited  \
# 0                  0.0           1                 1                  2
# 1                  0.0           1                 1                  2
# 2                  0.0           1                 2                  1
# 3                  0.0           1                 2                  1
# 4                  0.0           1                 1                  1
#
#    non-pat_refs  num_figures  num_assignees  priority_date
# 0           1.0          6.0              1           1980
# 1           1.0          6.0              1           1980
# 2           0.0          5.0              1           1980
# 3           0.0          5.0              1           1980
# 4           0.0          2.0              1           1980

# %%
focal = master[['patent_number','priority_date']]
focal.head()
# Out:
#   patent_number  priority_date
# 0       D257752           1980
# 1       D257924           1980
# 2       D258382           1980
# 3       D258383           1980
# 4       D258571           1980

# %%
citations.head()
# Out:
#   uspc_mainclass_id uspc_subclass_id patent_number
# 0               248          248/423       3930272
# 1               403          403/107       3930272
# 2                 5             5/11       3930272
# 3                 5            5/100       3930272
# 4                47         47/58.1R       3930335

# %%
focal_citation_link.head()
# Out:
#   cited_patent_number patent_number
# 0             4162014       D257752
# 1             4162014       D257924
# 2             D253842       D258382
# 3             D253842       D258383
# 4             D253842       D258678

# %%
focal_citation_link.isnull().sum()
# Out:
# cited_patent_number    0
# patent_number          0
# dtype: int64

# %%
focal_citation = pd.merge(focal, focal_citation_link, on='patent_number', how='left')
focal_citation.head()
# Out:
#   patent_number  priority_date cited_patent_number
# 0       D257752           1980             4162014
# 1       D257924           1980             4162014
# 2       D258382           1980             D253842
# 3       D258383           1980             D253842
# 4       D258571           1980                 NaN

# %%
focal_citation['patent_number'].nunique()
# Out:
# 525490

# %%
focal_citation.isnull().sum()
# Out:
# patent_number              0
# priority_date              0
# cited_patent_number    18363
# dtype: int64

# %% [markdown]
# Let's see what is null and why

# %%
focal_citation.loc[focal_citation['cited_patent_number'].isnull()]
# Out:
#         patent_number  priority_date cited_patent_number
# 4             D258571           1980                 NaN
# 5             D258650           1980                 NaN
# 8             D258760           1980                 NaN
# 21            D259183           1980                 NaN
# 45            D259575           1980                 NaN
# 46            D259610           1980                 NaN
# 56            D259669           1980                 NaN
# 63            D259753           1980                 NaN
# 65            D259820           1980                 NaN
# 75            D259959           1980                 NaN
# 77            D260020           1980                 NaN
# 82            D260062           1980                 NaN
# 83            D260068           1980                 NaN
# 91            D260233           1980                 NaN
# 93            D260297           1980                 NaN
# 94            D260320           1980                 NaN
# 96            D260337           1980                 NaN
# 101           D260416           1980                 NaN
# 109           D260560           1980                 NaN
# 110           D260567           1980                 NaN
# 111           D260592           1980                 NaN
# 112           D260633           1980                 NaN
# 113           D260687           1980                 NaN
# 116           D260719           1979                 NaN
# 117           D260722           1980                 NaN
# 119           D260747           1980                 NaN
# 121           D260803           1980                 NaN
# 122           D260809           1980                 NaN
# 123           D260829           1980                 NaN
# 128           D260839           1980                 NaN
# ...               ...            ...                 ...
# 5898261       D742662           2014                 NaN
# 5917476       D749461           2015                 NaN
# 5977445       D758734           2015                 NaN
# 5979458       D758896           2015                 NaN
# 5992969       D760113           2015                 NaN
# 6028245       D763404           2015                 NaN
# 6031466       D763708           2015                 NaN
# 6044208       D764824           2015                 NaN
# 6087067       D767979           2015                 NaN
# 6102184       D769150           2015                 NaN
# 6102745       D769205           2014                 NaN
# 6124649       D770186           2015                 NaN
# 6127088       D770328           2015                 NaN
# 6156190       D772301           2015                 NaN
# 6167055       D773004           2015                 NaN
# 6185747       D774301           2013                 NaN
# 6201189       D775297           2015                 NaN
# 6256902       D778957           2015                 NaN
# 6270484       D779816           2015                 NaN
# 6277622       D780296           2015                 NaN
# 6288380       D781001           2015                 NaN
# 6296837       D781732           2015                 NaN
# 6303539       D782176           2015                 NaN
# 6322822       D783709           2015                 NaN
# 6334529       D784707           2015                 NaN
# 6362326       D786952           2015                 NaN
# 6370477       D787764           2015                 NaN
# 6412378       D791822           2015                 NaN
# 6422085       D793043           2015                 NaN
# 6458208       D797582           2015                 NaN
#
# [18363 rows x 3 columns]

# %% [markdown]
# After viewing a sample, these patents either don't make references, rare, or all of their references are pre 1976, more common. Since they are not useful for analysis, I will drop them

# %%
# percentage of patents affected
focal_citation['cited_patent_number'].value_counts(normalize=True, dropna=False).head()
# Out:
# NaN        0.002822
# D504889    0.000077
# D337569    0.000071
# D341848    0.000068
# D561358    0.000059
# Name: cited_patent_number, dtype: float64

# %% [markdown]
# Less than 1 percent of patents are affected by this

# %%
focal_citation.dropna(inplace=True)
focal_citation.patent_number.nunique()
# Out:
# 507127

# %% [markdown]
# # current number of patents represened: 507,127

# %%
citations.rename(index=str, columns={'patent_number':'cited_patent_number'}, inplace=True)
focal_citation_citeclass = pd.merge(focal_citation, citations, on='cited_patent_number', how='left')
focal_citation_citeclass.patent_number.nunique()
# Out:
# 507127

# %%
focal_citation_citeclass.head()
# Out:
#   patent_number  priority_date cited_patent_number uspc_mainclass_id  \
# 0       D257752           1980             4162014               211
# 1       D257752           1980             4162014               211
# 2       D257752           1980             4162014               211
# 3       D257924           1980             4162014               211
# 4       D257924           1980             4162014               211
#
#   uspc_subclass_id
# 0           211/50
# 1           211/55
# 2        211/126.1
# 3           211/50
# 4           211/55

# %%
focal_citation_citeclass.rename(index=str, columns={'uspc_mainclass_id':'cite_mainclass', 'uspc_subclass_id':'cite_subclass'}, inplace=True)
focal_citation_citeclass.isnull().sum()
# Out:
# patent_number            0
# priority_date            0
# cited_patent_number      0
# cite_mainclass         530
# cite_subclass          530
# dtype: int64

# %% [markdown]
# Drop nulls. Without classification its useles

# %%
focal_citation_citeclass.dropna(inplace=True)
focal_citation_citeclass['patent_number'].nunique()
# Out:
# 507126

# %% [markdown]
# # Current number of patents represented: 507,126

# %%
final = pd.merge(focal_citation_citeclass, focal_class, on='patent_number', how='left')
final.head()
# Out:
#   patent_number  priority_date cited_patent_number cite_mainclass  \
# 0       D257752           1980             4162014            211
# 1       D257752           1980             4162014            211
# 2       D257752           1980             4162014            211
# 3       D257924           1980             4162014            211
# 4       D257924           1980             4162014            211
#
#   cite_subclass uspc_mainclass_id uspc_subclass_id
# 0        211/50               D19           D19/75
# 1        211/55               D19           D19/75
# 2     211/126.1               D19           D19/75
# 3        211/50               D06          D06/573
# 4        211/55               D06          D06/573

# %%
final.rename(index=str, columns={'uspc_mainclass_id':'focal_mainclass', 'uspc_subclass_id':'focal_subclass'}, inplace=True)

# %%
final.shape
# Out:
# (21778093, 7)

# %%
final.patent_number.nunique()
# Out:
# 507126

# %%
final.isnull().sum()
# Out:
# patent_number               0
# priority_date               0
# cited_patent_number         0
# cite_mainclass              0
# cite_subclass               0
# focal_mainclass        207651
# focal_subclass         207651
# dtype: int64

# %% [markdown]
# 4000 of our patents had null citations. These are mainly withdrawn patents and newly granted patent. I assume this has to do with patentsview getting updated information

# %%
final.dropna(inplace=True)
final['patent_number'].nunique()
# Out:
# 503128

# %% [markdown]
# # Current patent count: 503,128

# %% [markdown]
# Let's make this smaller to be easier for memory to deal with

# %%
final['patent_number'].nunique() /master['patent_number'].nunique()
# Out:
# 0.9574454318826239

# %% [markdown]
# 95.74% of the original dataset is still represented

# %%
final.head()
# Out:
#   patent_number  priority_date cited_patent_number cite_mainclass  \
# 0       D257752           1980             4162014            211
# 1       D257752           1980             4162014            211
# 2       D257752           1980             4162014            211
# 3       D257924           1980             4162014            211
# 4       D257924           1980             4162014            211
#
#   cite_subclass focal_mainclass focal_subclass
# 0        211/50             D19         D19/75
# 1        211/55             D19         D19/75
# 2     211/126.1             D19         D19/75
# 3        211/50             D06        D06/573
# 4        211/55             D06        D06/573

# %% [markdown]
# # Analysis with subclass granularity

# %%
final_combinations = final.drop(['cited_patent_number','cite_mainclass','focal_mainclass'], axis=1).drop_duplicates().sort_values(by=['priority_date','patent_number','focal_subclass'])
final_combinations.head()
# Out:
#         patent_number  priority_date cite_subclass focal_subclass
# 4602315       D466542           1902       D16/311        D16/303
# 4602316       D466542           1902         2/428        D16/303
# 4602317       D466542           1902         2/452        D16/303
# 4602318       D466542           1902         2/442        D16/303
# 4602320       D466542           1902         2/445        D16/303

# %%
#necessary for accurate indexing
final_combinations = final_combinations.sort_values('priority_date').reset_index(drop=True)
final_combinations.head()
# Out:
#   patent_number  priority_date cite_subclass focal_subclass
# 0       D466542           1902       D16/311        D16/303
# 1       D466542           1902         2/428        D16/303
# 2       D466542           1902         2/452        D16/303
# 3       D466542           1902         2/442        D16/303
# 4       D466542           1902         2/445        D16/303

# %%
final_combinations.shape
# Out:
# (11447580, 4)

# %% [markdown]
# 11,447,580 individual backwards ciations at the subclass level

# %%
final_combinations['first_seen'] = 0
final_combinations.head()
# Out:
#   patent_number  priority_date cite_subclass focal_subclass  first_seen
# 0       D466542           1902       D16/311        D16/303           0
# 1       D466542           1902         2/428        D16/303           0
# 2       D466542           1902         2/452        D16/303           0
# 3       D466542           1902         2/442        D16/303           0
# 4       D466542           1902         2/445        D16/303           0

# %% [markdown]
# Sort class pairs so they are reciprocal, drop the duplicates. This marks the all the first occurances since dataframe is sorted by year. The length of these indices will indicate how many unique class pairs exist

# %%
final_combinations.to_csv('data/final_combinations.csv', index_label=False)

# %% [markdown]
# # Analysis with mainclass granularity

# %%
final_combinations = final.drop(['cited_patent_number','cite_subclass','focal_subclass'], axis=1).drop_duplicates().sort_values(by=['priority_date','patent_number','focal_mainclass'])
final_combinations.head()
# Out:
#         patent_number  priority_date cite_mainclass focal_mainclass
# 4602315       D466542           1902            D16             D16
# 4602316       D466542           1902              2             D16
# 6144836       D499408           1904            312             D14
# 6144839       D499408           1904            D14             D14
# 6362160       D510547           1905            D12             D12

# %%
#necessary for accurate indexing
final_combinations = final_combinations.sort_values('priority_date').reset_index(drop=True)
final_combinations.head()
# Out:
#   patent_number  priority_date cite_mainclass focal_mainclass
# 0       D466542           1902            D16             D16
# 1       D466542           1902              2             D16
# 2       D499408           1904            312             D14
# 3       D499408           1904            D14             D14
# 4       D510547           1905            D12             D12

# %%
final_combinations.shape
# Out:
# (2371580, 4)

# %% [markdown]
# 2,371,580 individual backwards citations pairs at the mainclass level

# %%
final_combinations['first_seen'] = 0
final_combinations.head()
# Out:
#   patent_number  priority_date cite_mainclass focal_mainclass  first_seen
# 0       D466542           1902            D16             D16           0
# 1       D466542           1902              2             D16           0
# 2       D499408           1904            312             D14           0
# 3       D499408           1904            D14             D14           0
# 4       D510547           1905            D12             D12           0

# %%
final_combinations.to_csv('data/final_combinations_main.csv', index_label=False)

# %%
master
# Out:
#        patent_number  grant_year  app_year  num_inventors  us_inventor  \
# 0            D257752        1981      1980              1          1.0
# 1            D257924        1981      1980              1          1.0
# 2            D258382        1981      1980              2          1.0
# 3            D258383        1981      1980              2          1.0
# 4            D258571        1981      1980              1          1.0
# 5            D258650        1981      1980              3          1.0
# 6            D258678        1981      1980              2          1.0
# 7            D258755        1981      1980              2          1.0
# 8            D258760        1981      1980              1          1.0
# 9            D258766        1981      1980              1          1.0
# 10           D258990        1981      1980              1          1.0
# 11           D259183        1981      1980              1          1.0
# 12           D259247        1981      1980              1          1.0
# 13           D259248        1981      1980              1          1.0
# 14           D259249        1981      1980              1          1.0
# 15           D259250        1981      1980              1          1.0
# 16           D259251        1981      1980              1          1.0
# 17           D259281        1981      1980              1          1.0
# 18           D259334        1981      1980              1          1.0
# 19           D259438        1981      1980              1          1.0
# 20           D259509        1981      1980              2          1.0
# 21           D259510        1981      1980              1          1.0
# 22           D259575        1981      1980              1          1.0
# 23           D259610        1981      1980              1          1.0
# 24           D259611        1981      1980              1          1.0
# 25           D259621        1981      1980              1          1.0
# 26           D259622        1981      1980              1          1.0
# 27           D259623        1981      1980              1          1.0
# 28           D259624        1981      1980              1          1.0
# 29           D259669        1981      1980              1          1.0
# ...              ...         ...       ...            ...          ...
# 525460       D806187        2017      2015              1          1.0
# 525461       D806194        2017      2015              1          1.0
# 525462       D806196        2017      2015              4          1.0
# 525463       D806209        2017      2015              1          0.0
# 525464       D806219        2017      2015              2          0.0
# 525465       D806220        2017      2015              2          0.0
# 525466       D806221        2017      2015              2          0.0
# 525467       D806222        2017      2015              2          0.0
# 525468       D806225        2017      2015              2          0.0
# 525469       D806231        2017      2015              1          1.0
# 525470       D806237        2017      2015              2          0.0
# 525471       D806238        2017      2015              2          0.0
# 525472       D806240        2017      2015              4          1.0
# 525473       D806244        2017      2015              4          1.0
# 525474       D806249        2017      2015              4          0.0
# 525475       D806257        2017      2015              4          1.0
# 525476       D806262        2017      2015              2          1.0
# 525477       D806269        2017      2015              2          0.0
# 525478       D806294        2017      2015              2          1.0
# 525479       D806295        2017      2015              2          1.0
# 525480       D806296        2017      2015              1          1.0
# 525481       D806308        2017      2015              4          1.0
# 525482       D806310        2017      2015              4          0.0
# 525483       D806312        2017      2015              1          0.0
# 525484       D806313        2017      2015              2          1.0
# 525485       D806321        2017      2015              1          1.0
# 525486       D806324        2017      2015              2          1.0
# 525487       D806336        2017      2015              3          1.0
# 525488       D806337        2017      2015              2          1.0
# 525489       D806338        2017      2015              2          1.0
#
#         cite_foreign_patent  is_missing  num_design_cited  num_utility_cited  \
# 0                       0.0           1                 1                  2
# 1                       0.0           1                 1                  2
# 2                       0.0           1                 2                  1
# 3                       0.0           1                 2                  1
# 4                       0.0           1                 1                  1
# 5                       0.0           1                 1                  1
# 6                       0.0           1                 2                  1
# 7                       0.0           1                 2                  1
# 8                       0.0           1                 1                  1
# 9                       0.0           1                 1                 11
# 10                      0.0           1                 3                  1
# 11                      1.0           1                 1                  1
# 12                      0.0           1                 3                  1
# 13                      0.0           1                 3                  1
# 14                      0.0           1                 3                  1
# 15                      0.0           1                 3                  1
# 16                      0.0           1                 3                  1
# 17                      0.0           1                 1                  2
# 18                      0.0           1                 3                  1
# 19                      0.0           1                 2                  1
# 20                      0.0           0                 3                  2
# 21                      0.0           1                 4                  2
# 22                      0.0           1                 1                  1
# 23                      0.0           1                 1                  1
# 24                      0.0           1                 2                  1
# 25                      0.0           1                 3                  1
# 26                      0.0           1                 3                  1
# 27                      0.0           1                 3                  1
# 28                      0.0           1                 3                  1
# 29                      0.0           1                 1                  1
# ...                     ...         ...               ...                ...
# 525460                  0.0           1                 4                  4
# 525461                  0.0           1                10                  4
# 525462                  0.0           0                15                 21
# 525463                  1.0           0                 9                  1
# 525464                  0.0           0                 5                  0
# 525465                  0.0           0                11                  0
# 525466                  0.0           0                 4                  1
# 525467                  0.0           0                 6                  0
# 525468                  0.0           0                12                  1
# 525469                  0.0           0                20                  6
# 525470                  0.0           0                 7                  1
# 525471                  0.0           0                 4                  2
# 525472                  0.0           1                11                  1
# 525473                  1.0           0                13                 21
# 525474                  1.0           0                13                  2
# 525475                  0.0           1                10                 10
# 525476                  0.0           0                 3                  2
# 525477                  1.0           1                 9                  2
# 525478                  0.0           0                16                  0
# 525479                  1.0           1                49                 14
# 525480                  0.0           1                11                  1
# 525481                  1.0           1                16                  3
# 525482                  1.0           1                27                  2
# 525483                  0.0           1                31                  1
# 525484                  0.0           1                19                  3
# 525485                  0.0           0                 5                  4
# 525486                  0.0           1                22                  3
# 525487                  0.0           0                 3                  0
# 525488                  1.0           1                11                  3
# 525489                  1.0           0                18                  0
#
#         non-pat_refs  num_figures  num_assignees  priority_date
# 0                1.0          6.0              1           1980
# 1                1.0          6.0              1           1980
# 2                0.0          5.0              1           1980
# 3                0.0          5.0              1           1980
# 4                0.0          2.0              1           1980
# 5                0.0          6.0              1           1980
# 6                0.0          5.0              1           1980
# 7                0.0          5.0              1           1980
# 8                0.0          6.0              1           1980
# 9                0.0          3.0              1           1980
# 10               0.0          6.0              1           1980
# 11               0.0          2.0              1           1980
# 12               1.0          2.0              1           1980
# 13               1.0          2.0              1           1980
# 14               1.0          2.0              1           1980
# 15               1.0          2.0              1           1980
# 16               1.0          1.0              1           1980
# 17               2.0          7.0              1           1980
# 18               1.0          2.0              1           1980
# 19               0.0          8.0              1           1980
# 20               0.0          7.0              1           1980
# 21               0.0          5.0              1           1980
# 22               1.0          4.0              1           1980
# 23               1.0          6.0              1           1980
# 24               1.0          6.0              1           1980
# 25               1.0          2.0              1           1980
# 26               1.0          2.0              1           1980
# 27               1.0          2.0              1           1980
# 28               1.0          2.0              1           1980
# 29               0.0          5.0              1           1980
# ...              ...          ...            ...            ...
# 525460           1.0          8.0              1           2015
# 525461           0.0          6.0              1           2015
# 525462           0.0          6.0              1           2015
# 525463           2.0         15.0              1           2015
# 525464           0.0          6.0              1           2015
# 525465           0.0          3.0              1           2015
# 525466           0.0          6.0              1           2015
# 525467           0.0          4.0              1           2015
# 525468           0.0         10.0              1           2015
# 525469           0.0          7.0              1           2015
# 525470           0.0          7.0              1           2014
# 525471           0.0          8.0              1           2015
# 525472           0.0          6.0              1           2015
# 525473           6.0          5.0              1           2014
# 525474           0.0         27.0              1           2014
# 525475           1.0          7.0              1           2015
# 525476           0.0          6.0              1           2015
# 525477           0.0          2.0              1           2015
# 525478           0.0          8.0              1           2015
# 525479           0.0          8.0              1           2015
# 525480           0.0          6.0              1           2015
# 525481           0.0          5.0              1           2012
# 525482           0.0         16.0              1           2015
# 525483           1.0         15.0              1           2015
# 525484           2.0          8.0              1           2015
# 525485           2.0          8.0              1           2015
# 525486           4.0         18.0              1           2015
# 525487           0.0          6.0              1           2015
# 525488           2.0          5.0              1           2015
# 525489           1.0          9.0              1           2015
#
# [525490 rows x 13 columns]
