# %% [markdown]
# This notebook explores the robustness of the eight measures at the patent and industrial level.
#
# The eight measures are listed below
#
# # At the patent value
#
# Binary main class D-D
#
# Binary sub class D-D
#
# Continuous main class D-D
#
# Continuous sub class D-D
#
# Binary main class D-U
#
# Binary sub class D-U
#
# Continuous main class D-U
#
# Continuous sub class D-U
#
# # At the industry level
# Binary main class (%) D-D
#
# Binary sub class (%) D-D
#
# Continuous main class (mean of max scores) D-D
#
# Continuous sub class (mean of max scores) D-D
#
# Binary main class (%) D-U
#
# Binary sub class (%) D-U
#
# Continuous main class (mean of max scores) D-U
#
# Continuous sub class (mean of max scores) D-U

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import design_class_dictionary

# %matplotlib inline

# %%
#reading in data
master = pd.read_csv('data/master_503107.csv')
master.head()
# Out:
#   patent_number  grant_year  app_year  num_inventors  us_inventor  \
# 0       D257752        1981      1980              1            1
# 1       D257924        1981      1980              1            1
# 2       D258382        1981      1980              2            1
# 3       D258383        1981      1980              2            1
# 4       D258678        1981      1980              2            1
#
#    cite_foreign_patent  is_missing  num_design_cited  num_utility_cited  \
# 0                    0           1                 1                  2
# 1                    0           1                 1                  2
# 2                    0           1                 2                  1
# 3                    0           1                 2                  1
# 4                    0           1                 2                  1
#
#    non-pat_refs  num_figures  num_assignees  missing_data family_size  \
# 0             1            6              1             0           1
# 1             1            6              1             0           1
# 2             0            5              1             0           1
# 3             0            5              1             0           1
# 4             0            5              1             0           1
#
#   country_transformed  priority_year
# 0                  US         1980.0
# 1                  US         1980.0
# 2                  US         1980.0
# 3                  US         1980.0
# 4                  US         1980.0

# %%
binary_main_d = pd.read_csv('data/d2d_main_binary.csv')
binary_sub_d = pd.read_csv('data/d2d_sub_binary.csv')
cont_main_d = pd.read_csv('data/d2d_main_cont.csv')
cont_sub_d = pd.read_csv('data/d2d_sub_cont.csv')

binary_main_u = pd.read_csv('data/d2u_main_binary.csv')
binary_sub_u = pd.read_csv('data/d2u_sub_binary.csv')
cont_main_u = pd.read_csv('data/d2u_main_cont.csv')
cont_sub_u = pd.read_csv('data/d2u_sub_cont.csv')

# %%
binary_main_d.head()
# Out:
#   patent_number  is novel  novelty count
# 0       D258382         0              0
# 1       D258383         0              0
# 2       D258678         0              0
# 3       D258755         0              0
# 4       D258990         1              2

# %%
cont_main_d.head()
# Out:
#   patent_number  max_novelty
# 0       D258382    -0.797657
# 1       D258383    -0.797657
# 2       D258678    -0.797657
# 3       D258755    -0.797657
# 4       D258990     0.809274

# %% [markdown]
# # Explore at the patent level first

# %%
def add_column(df, column, column_name):
    df = pd.merge(df, column, on='patent_number', how='left')
    return df

# %%
# Merge the binary measures into master dataframe

master = pd.merge(master, binary_main_d, on='patent_number', how='left')
master = master.rename(index=str, columns={'is novel':'is novel binary main: D-D',\
                                  'novelty count':'novelty count binary main: D-D'})

master = pd.merge(master, binary_sub_d, on='patent_number', how='left' )
master = master.rename(index=str, columns={'is novel':'is novel binary sub: D-D',\
                                          'novelty count':'novelty count binary sub: D-D'})

master = pd.merge(master, binary_sub_u, on='patent_number', how='left')
master = master.rename(index=str, columns={'is novel':'is novel binary main: D-U',\
                                          'novelty count':'novelty count binary main: D-U'})

master = pd.merge(master, binary_sub_u, on='patent_number', how='left')
master = master.rename(index=str, columns={'is novel':'is novel binary sub: D-U',\
                                          'novelty count':'novelty count binary sub: D-U'})

# %%
# merge the continuous into master dataframe

master = pd.merge(master, cont_main_d, on='patent_number', how='left')
master = master.rename(index=str, columns={'max_novelty':'max novelty main: D-D'})

master = pd.merge(master, cont_sub_d, on='patent_number', how='left' )
master = master.rename(index=str, columns={'max_novelty':'max novelty sub: D-D'})

master = pd.merge(master, cont_sub_u, on='patent_number', how='left')
master = master.rename(index=str, columns={'max_novelty':'max novelty main: D-U'})

master = pd.merge(master, cont_sub_u, on='patent_number', how='left')
master = master.rename(index=str, columns={'max_novelty':'max novelty sub: D-U'})

# %%
#select the columns with just the measures
columns = master[['is novel binary main: D-D','is novel binary sub: D-D',\
        'is novel binary main: D-U','is novel binary sub: D-U','max novelty main: D-D',\
        'max novelty sub: D-D','max novelty main: D-U','max novelty sub: D-U']]
columns.head()
# Out:
#    is novel binary main: D-D  is novel binary sub: D-D  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        0.0                       1.0
# 3                        0.0                       1.0
# 4                        0.0                       1.0
#
#    is novel binary main: D-U  is novel binary sub: D-U  max novelty main: D-D  \
# 0                        1.0                       1.0                    NaN
# 1                        1.0                       1.0                    NaN
# 2                        NaN                       NaN              -0.797657
# 3                        NaN                       NaN              -0.797657
# 4                        NaN                       NaN              -0.797657
#
#    max novelty sub: D-D  max novelty main: D-U  max novelty sub: D-U
# 0                   NaN              -4.951017             -4.951017
# 1                   NaN              -5.724207             -5.724207
# 2             -5.392617                    NaN                   NaN
# 3             -5.392617                    NaN                   NaN
# 4             -5.392617                    NaN                   NaN

# %% [markdown]
# Examing the correlation of design citing design measures for binary and continous measures, at mainclass and subclass level

# %%
matrix = columns[['is novel binary main: D-D','is novel binary sub: D-D','max novelty main: D-D',\
                  'max novelty sub: D-D']].dropna()

# count the number of observations
matrix.shape
# Out:
# (475267, 4)

# %% [markdown]
# There are 475,267 non-null observations for these measures

# %%
#correlation matrix
matrix.corr().round(3)
# Out:
#                            is novel binary main: D-D  \
# is novel binary main: D-D                      1.000
# is novel binary sub: D-D                       0.066
# max novelty main: D-D                          0.038
# max novelty sub: D-D                          -0.012
#
#                            is novel binary sub: D-D  max novelty main: D-D  \
# is novel binary main: D-D                     0.066                  0.038
# is novel binary sub: D-D                      1.000                  0.478
# max novelty main: D-D                         0.478                  1.000
# max novelty sub: D-D                          0.255                  0.475
#
#                            max novelty sub: D-D
# is novel binary main: D-D                -0.012
# is novel binary sub: D-D                  0.255
# max novelty main: D-D                     0.475
# max novelty sub: D-D                      1.000

# %% [markdown]
# Examing the correlation of design citing utility measures for binary and continous measures, at mainclass and subclass level

# %%
matrix = columns[['is novel binary main: D-U','is novel binary sub: D-U','max novelty main: D-U',\
                  'max novelty sub: D-U']].dropna()

#count the number of observations
matrix.shape
# Out:
# (308725, 4)

# %% [markdown]
# There are 308,725 non-null observations for these measures

# %%
matrix.corr().round(3)
# Out:
#                            is novel binary main: D-U  \
# is novel binary main: D-U                      1.000
# is novel binary sub: D-U                       1.000
# max novelty main: D-U                          0.168
# max novelty sub: D-U                           0.168
#
#                            is novel binary sub: D-U  max novelty main: D-U  \
# is novel binary main: D-U                     1.000                  0.168
# is novel binary sub: D-U                      1.000                  0.168
# max novelty main: D-U                         0.168                  1.000
# max novelty sub: D-U                          0.168                  1.000
#
#                            max novelty sub: D-U
# is novel binary main: D-U                 0.168
# is novel binary sub: D-U                  0.168
# max novelty main: D-U                     1.000
# max novelty sub: D-U                      1.000

# %% [markdown]
# Comparing all 8 measures

# %%
matrix = columns.dropna()

#count the number of observations
matrix.shape
# Out:
# (280885, 8)

# %% [markdown]
# There are 280,885 observations

# %%
matrix.corr().round(3)
# Out:
#                            is novel binary main: D-D  \
# is novel binary main: D-D                      1.000
# is novel binary sub: D-D                       0.049
# is novel binary main: D-U                      0.024
# is novel binary sub: D-U                       0.024
# max novelty main: D-D                          0.028
# max novelty sub: D-D                          -0.009
# max novelty main: D-U                         -0.010
# max novelty sub: D-U                          -0.010
#
#                            is novel binary sub: D-D  \
# is novel binary main: D-D                     0.049
# is novel binary sub: D-D                      1.000
# is novel binary main: D-U                     0.328
# is novel binary sub: D-U                      0.328
# max novelty main: D-D                         0.483
# max novelty sub: D-D                          0.282
# max novelty main: D-U                         0.105
# max novelty sub: D-U                          0.105
#
#                            is novel binary main: D-U  \
# is novel binary main: D-D                      0.024
# is novel binary sub: D-D                       0.328
# is novel binary main: D-U                      1.000
# is novel binary sub: D-U                       1.000
# max novelty main: D-D                          0.181
# max novelty sub: D-D                           0.088
# max novelty main: D-U                          0.192
# max novelty sub: D-U                           0.192
#
#                            is novel binary sub: D-U  max novelty main: D-D  \
# is novel binary main: D-D                     0.024                  0.028
# is novel binary sub: D-D                      0.328                  0.483
# is novel binary main: D-U                     1.000                  0.181
# is novel binary sub: D-U                      1.000                  0.181
# max novelty main: D-D                         0.181                  1.000
# max novelty sub: D-D                          0.088                  0.487
# max novelty main: D-U                         0.192                  0.235
# max novelty sub: D-U                          0.192                  0.235
#
#                            max novelty sub: D-D  max novelty main: D-U  \
# is novel binary main: D-D                -0.009                 -0.010
# is novel binary sub: D-D                  0.282                  0.105
# is novel binary main: D-U                 0.088                  0.192
# is novel binary sub: D-U                  0.088                  0.192
# max novelty main: D-D                     0.487                  0.235
# max novelty sub: D-D                      1.000                  0.591
# max novelty main: D-U                     0.591                  1.000
# max novelty sub: D-U                      0.591                  1.000
#
#                            max novelty sub: D-U
# is novel binary main: D-D                -0.010
# is novel binary sub: D-D                  0.105
# is novel binary main: D-U                 0.192
# is novel binary sub: D-U                  0.192
# max novelty main: D-D                     0.235
# max novelty sub: D-D                      0.591
# max novelty main: D-U                     1.000
# max novelty sub: D-U                      1.000

# %%
#save the table
matrix.to_csv('data/design_cite_design_design_cite_utility_corr.csv')

# %% [markdown]
# # Examing at the industrial level

# %% [markdown]
# We need to attribute each patent to an industry. I have taken the first listed class, known as primary class, of a patent as the industry

# %%
# read in the data file from PatStat that lists all patent classes and their sequences
pat_class = pd.read_csv('data/uspc_current.tsv', delimiter='\t', usecols=['patent_id','mainclass_id','sequence'],\
                        dtype={'patent_id':str})
pat_class.head()
# Out:
#   patent_id mainclass_id  sequence
# 0   3930271            2         0
# 1   3930271            2         1
# 2   3930271            2         2
# 3   3930271          473         3
# 4   3930272            5         0

# %%
#select first listed class
pat_class_first = pat_class.loc[pat_class.sequence == 0]
master = pd.merge(master, pat_class_first, left_on='patent_number',right_on='patent_id', how='left')

# %%
master.head()
# Out:
#   patent_number  grant_year  app_year  num_inventors  us_inventor  \
# 0       D257752        1981      1980              1            1
# 1       D257924        1981      1980              1            1
# 2       D258382        1981      1980              2            1
# 3       D258383        1981      1980              2            1
# 4       D258678        1981      1980              2            1
#
#    cite_foreign_patent  is_missing  num_design_cited  num_utility_cited  \
# 0                    0           1                 1                  2
# 1                    0           1                 1                  2
# 2                    0           1                 2                  1
# 3                    0           1                 2                  1
# 4                    0           1                 2                  1
#
#    non-pat_refs    ...     novelty count binary main: D-U  \
# 0             1    ...                                3.0
# 1             1    ...                                3.0
# 2             0    ...                                NaN
# 3             0    ...                                NaN
# 4             0    ...                                NaN
#
#    is novel binary sub: D-U  novelty count binary sub: D-U  \
# 0                       1.0                            3.0
# 1                       1.0                            3.0
# 2                       NaN                            NaN
# 3                       NaN                            NaN
# 4                       NaN                            NaN
#
#   max novelty main: D-D max novelty sub: D-D  max novelty main: D-U  \
# 0                   NaN                  NaN              -4.951017
# 1                   NaN                  NaN              -5.724207
# 2             -0.797657            -5.392617                    NaN
# 3             -0.797657            -5.392617                    NaN
# 4             -0.797657            -5.392617                    NaN
#
#    max novelty sub: D-U  patent_id  mainclass_id  sequence
# 0             -4.951017    D257752           D19       0.0
# 1             -5.724207    D257924           D06       0.0
# 2                   NaN    D258382           D23       0.0
# 3                   NaN    D258383           D23       0.0
# 4                   NaN    D258678           D23       0.0
#
# [5 rows x 31 columns]

# %%
#Checking the primary classes of these patents for uniformity or unexpected values
master.mainclass_id.unique()
# Out:
# array(['D19', 'D06', 'D23', 'D25', 'D09', 'D24', 'D11', 'D12', 'D21',
#        'D08', 'D10', 'D07', 'D22', 'D02', 'D13', 'D34', 'D17', 'D18',
#        'D30', 'D14', 'D32', 'D28', 'D03', 'D27', 'D05', 'D15', 'D26',
#        'D16', 'D20', 'D99', 'D04', 'D01', 'D29', 'D8', 'D9', 'D6', 'D7',
#        '1', '70', '24', nan], dtype=object)

# %%
# harmonize the class names. ie D8 -> D08
master['mainclass_id'] = master['mainclass_id'].replace(design_class_dictionary.class_dictionary)

# %%
# Dropping the null value, it's useless
master = master.dropna(subset=['mainclass_id'])

#Selecting only valid primary design classes
master = master.loc[master.mainclass_id.str.contains('D')]

# %%
#selecting the columns of the measures and the primary classes
columns = master[['is novel binary main: D-D','is novel binary sub: D-D',\
        'is novel binary main: D-U','is novel binary sub: D-U','max novelty main: D-D',\
        'max novelty sub: D-D','max novelty main: D-U','max novelty sub: D-U', 'mainclass_id']]
columns.head()
# Out:
#    is novel binary main: D-D  is novel binary sub: D-D  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        0.0                       1.0
# 3                        0.0                       1.0
# 4                        0.0                       1.0
#
#    is novel binary main: D-U  is novel binary sub: D-U  max novelty main: D-D  \
# 0                        1.0                       1.0                    NaN
# 1                        1.0                       1.0                    NaN
# 2                        NaN                       NaN              -0.797657
# 3                        NaN                       NaN              -0.797657
# 4                        NaN                       NaN              -0.797657
#
#    max novelty sub: D-D  max novelty main: D-U  max novelty sub: D-U  \
# 0                   NaN              -4.951017             -4.951017
# 1                   NaN              -5.724207             -5.724207
# 2             -5.392617                    NaN                   NaN
# 3             -5.392617                    NaN                   NaN
# 4             -5.392617                    NaN                   NaN
#
#   mainclass_id
# 0          D19
# 1          D06
# 2          D23
# 3          D23
# 4          D23

# %%
'''
Creating the table of measures consolidated at the industry level
The mean is taken for the max novelty and binary measures
Since the binary measure only takes on the value of 1 or 0, the mean is equivalent
calculating the percentage of positive occurences
'''
table = columns.groupby('mainclass_id').mean().round(3).reset_index()
table['class name'] = table['mainclass_id'].map(design_class_dictionary.class_labels)
table
# Out:
#    mainclass_id  is novel binary main: D-D  is novel binary sub: D-D  \
# 0           D01                      0.007                     0.640
# 1           D02                      0.002                     0.288
# 2           D03                      0.003                     0.456
# 3           D04                      0.007                     0.316
# 4           D05                      0.009                     0.516
# 5           D06                      0.002                     0.387
# 6           D07                      0.002                     0.414
# 7           D08                      0.001                     0.312
# 8           D09                      0.002                     0.499
# 9           D10                      0.002                     0.290
# 10          D11                      0.004                     0.450
# 11          D12                      0.001                     0.216
# 12          D13                      0.001                     0.226
# 13          D14                      0.001                     0.292
# 14          D15                      0.003                     0.254
# 15          D16                      0.002                     0.246
# 16          D17                      0.014                     0.270
# 17          D18                      0.003                     0.250
# 18          D19                      0.006                     0.544
# 19          D20                      0.004                     0.498
# 20          D21                      0.002                     0.419
# 21          D22                      0.002                     0.209
# 22          D23                      0.002                     0.250
# 23          D24                      0.005                     0.316
# 24          D25                      0.002                     0.250
# 25          D26                      0.001                     0.256
# 26          D27                      0.015                     0.529
# 27          D28                      0.004                     0.347
# 28          D29                      0.006                     0.337
# 29          D30                      0.004                     0.537
# 30          D32                      0.002                     0.271
# 31          D34                      0.003                     0.323
# 32          D99                      0.013                     0.537
#
#     is novel binary main: D-U  is novel binary sub: D-U  \
# 0                       0.806                     0.806
# 1                       0.575                     0.575
# 2                       0.774                     0.774
# 3                       0.663                     0.663
# 4                       0.818                     0.818
# 5                       0.741                     0.741
# 6                       0.706                     0.706
# 7                       0.710                     0.710
# 8                       0.763                     0.763
# 9                       0.740                     0.740
# 10                      0.706                     0.706
# 11                      0.687                     0.687
# 12                      0.634                     0.634
# 13                      0.607                     0.607
# 14                      0.753                     0.753
# 15                      0.538                     0.538
# 16                      0.547                     0.547
# 17                      0.605                     0.605
# 18                      0.788                     0.788
# 19                      0.836                     0.836
# 20                      0.685                     0.685
# 21                      0.541                     0.541
# 22                      0.744                     0.744
# 23                      0.651                     0.651
# 24                      0.729                     0.729
# 25                      0.710                     0.710
# 26                      0.762                     0.762
# 27                      0.644                     0.644
# 28                      0.646                     0.646
# 29                      0.708                     0.708
# 30                      0.664                     0.664
# 31                      0.721                     0.721
# 32                      0.735                     0.735
#
#     max novelty main: D-D  max novelty sub: D-D  max novelty main: D-U  \
# 0                   0.506                -2.838                 -4.785
# 1                  -0.895                -2.476                 -4.426
# 2                   0.871                -2.420                 -3.880
# 3                  -0.728                -3.260                 -4.247
# 4                   0.018                -2.961                 -3.922
# 5                   0.620                -2.961                 -4.738
# 6                   0.655                -2.539                 -4.115
# 7                   0.653                -3.101                 -4.505
# 8                   0.754                -0.651                 -2.995
# 9                   0.241                -3.221                 -5.214
# 10                  0.476                -3.253                 -5.328
# 11                 -0.511                -4.622                 -5.813
# 12                  0.228                -2.851                 -4.219
# 13                  0.550                -1.972                 -3.619
# 14                 -0.191                -4.292                 -5.242
# 15                 -0.935                -3.306                 -4.912
# 16                 -1.549                -4.667                 -6.299
# 17                 -0.218                -3.631                 -5.647
# 18                  0.980                -1.911                 -4.304
# 19                  1.033                -2.726                 -4.277
# 20                  0.419                -4.658                 -5.604
# 21                 -1.145                -5.135                 -5.847
# 22                  0.032                -3.845                 -4.932
# 23                  0.606                -3.167                 -4.310
# 24                 -0.899                -4.600                 -4.851
# 25                 -0.385                -3.273                 -3.969
# 26                 -0.440                -4.009                 -5.755
# 27                  0.231                -3.846                 -5.399
# 28                 -0.223                -4.404                 -4.826
# 29                  0.935                -2.816                 -4.727
# 30                 -0.270                -4.110                 -4.888
# 31                  0.179                -3.377                 -4.353
# 32                  0.885                -3.319                 -5.331
#
#     max novelty sub: D-U                                         class name
# 0                 -4.785                                    Edible Products
# 1                 -4.426                           Apparel and Haberdashery
# 2                 -3.880  Travel Goods, Personal Belongings, and Storage...
# 3                 -4.247                                          Brushware
# 4                 -3.922        Textile or Paper Yard Goods; Sheet Material
# 5                 -4.738                                        Furnishings
# 6                 -4.115  Equipment for Preparing or Serving Food or Dri...
# 7                 -4.505                                 Tools and Hardware
# 8                 -2.995                  Packages and Containers for Goods
# 9                 -5.214        Measuring, Testing or Signaling Instruments
# 10                -5.328          Jewelry, Symbolic Insignia, and Ornaments
# 11                -5.813                                     Transportation
# 12                -4.219  Equipment for Production, Distribution, or Tra...
# 13                -3.619  Recording, Communication, or Information Retri...
# 14                -5.242                   Machines Not Elsewhere Specified
# 15                -4.912                  Photography and Optical Equipment
# 16                -6.299                                Musical Instruments
# 17                -5.647                      Printing and Office Machinery
# 18                -4.304  Office Supplies; Artists' and Teachers' Materials
# 19                -4.277                    Sales and Advertising Equipment
# 20                -5.604                       Games, Toys and Sports Goods
# 21                -5.847  Arms, Pyrotechnics, Hunting and Fishing Equipment
# 22                -4.932  Environmental Heating and Cooling, Fluid Handl...
# 23                -4.310                   Medical and Laboratory Equipment
# 24                -4.851           Building Units and Construction Elements
# 25                -3.969                                           Lighting
# 26                -5.755                      Tobacco and Smokers' Supplies
# 27                -5.399              Cosmetic Products and Toilet Articles
# 28                -4.826        Equipment for Safety, Protection and Rescue
# 29                -4.727                                   Animal Husbandry
# 30                -4.888               Washing, Cleaning or Drying Machines
# 31                -4.353             Material or Article Handling Equipment
# 32                -5.331                                      Miscellaneous

# %%
#save this table
table.to_csv('data/table.csv')

# %%
#correlation of measures at the industry level
table.corr().round(3)
# Out:
#                            is novel binary main: D-D  \
# is novel binary main: D-D                      1.000
# is novel binary sub: D-D                       0.476
# is novel binary main: D-U                      0.134
# is novel binary sub: D-U                       0.134
# max novelty main: D-D                         -0.129
# max novelty sub: D-D                          -0.148
# max novelty main: D-U                         -0.333
# max novelty sub: D-U                          -0.333
#
#                            is novel binary sub: D-D  \
# is novel binary main: D-D                     0.476
# is novel binary sub: D-D                      1.000
# is novel binary main: D-U                     0.664
# is novel binary sub: D-U                      0.664
# max novelty main: D-D                         0.629
# max novelty sub: D-D                          0.473
# max novelty main: D-U                         0.231
# max novelty sub: D-U                          0.231
#
#                            is novel binary main: D-U  \
# is novel binary main: D-D                      0.134
# is novel binary sub: D-D                       0.664
# is novel binary main: D-U                      1.000
# is novel binary sub: D-U                       1.000
# max novelty main: D-D                          0.620
# max novelty sub: D-D                           0.339
# max novelty main: D-U                          0.338
# max novelty sub: D-U                           0.338
#
#                            is novel binary sub: D-U  max novelty main: D-D  \
# is novel binary main: D-D                     0.134                 -0.129
# is novel binary sub: D-D                      0.664                  0.629
# is novel binary main: D-U                     1.000                  0.620
# is novel binary sub: D-U                      1.000                  0.620
# max novelty main: D-D                         0.620                  1.000
# max novelty sub: D-D                          0.339                  0.620
# max novelty main: D-U                         0.338                  0.470
# max novelty sub: D-U                          0.338                  0.470
#
#                            max novelty sub: D-D  max novelty main: D-U  \
# is novel binary main: D-D                -0.148                 -0.333
# is novel binary sub: D-D                  0.473                  0.231
# is novel binary main: D-U                 0.339                  0.338
# is novel binary sub: D-U                  0.339                  0.338
# max novelty main: D-D                     0.620                  0.470
# max novelty sub: D-D                      1.000                  0.816
# max novelty main: D-U                     0.816                  1.000
# max novelty sub: D-U                      0.816                  1.000
#
#                            max novelty sub: D-U
# is novel binary main: D-D                -0.333
# is novel binary sub: D-D                  0.231
# is novel binary main: D-U                 0.338
# is novel binary sub: D-U                  0.338
# max novelty main: D-D                     0.470
# max novelty sub: D-D                      0.816
# max novelty main: D-U                     1.000
# max novelty sub: D-U                      1.000

# %%
#Save the correlation table
table.corr().round(3).to_csv('data/corr_table.csv')

# %% [markdown]
# Examin if there is a correlation between the above measures and if a patent experiences multiple binary pairs

# %%
# If the binary count is larger than 1, then the patent is marked as having multiple binary novelty
master['multiple novelty main: D-D'] = np.where(master['novelty count binary main: D-D'] > 1,1,0)
master['multiple novelty main: D-U'] = np.where(master['novelty count binary main: D-U'] > 1,1,0)
master['multiple novelty sub: D-D'] = np.where(master['novelty count binary sub: D-D'] > 1,1,0)
master['multiple novelty sub: D-U'] = np.where(master['novelty count binary sub: D-U'] > 1,1,0)

# %%
#Creating the measures table at the industry level that includes multiple binary
columns = master[['is novel binary main: D-D',\
                 'multiple novelty main: D-D',\
                 'is novel binary sub: D-D',\
                 'multiple novelty sub: D-D',\
                 'is novel binary main: D-U',\
                 'multiple novelty main: D-U',\
                 'is novel binary sub: D-U',\
                 'multiple novelty sub: D-U',\
                 'max novelty main: D-D',\
                 'max novelty sub: D-D',\
                 'max novelty main: D-U',\
                 'max novelty sub: D-U', \
                 'mainclass_id']]
table = columns.groupby('mainclass_id').mean().round(3).reset_index()
table['class name'] = table['mainclass_id'].map(design_class_dictionary.class_labels)
table
# Out:
#    mainclass_id  is novel binary main: D-D  multiple novelty main: D-D  \
# 0           D01                      0.007                       0.001
# 1           D02                      0.002                       0.000
# 2           D03                      0.003                       0.001
# 3           D04                      0.007                       0.001
# 4           D05                      0.009                       0.001
# 5           D06                      0.002                       0.000
# 6           D07                      0.002                       0.001
# 7           D08                      0.001                       0.000
# 8           D09                      0.002                       0.001
# 9           D10                      0.002                       0.000
# 10          D11                      0.004                       0.001
# 11          D12                      0.001                       0.000
# 12          D13                      0.001                       0.000
# 13          D14                      0.001                       0.000
# 14          D15                      0.003                       0.001
# 15          D16                      0.002                       0.000
# 16          D17                      0.014                       0.002
# 17          D18                      0.003                       0.000
# 18          D19                      0.006                       0.002
# 19          D20                      0.004                       0.001
# 20          D21                      0.002                       0.001
# 21          D22                      0.002                       0.000
# 22          D23                      0.002                       0.000
# 23          D24                      0.005                       0.002
# 24          D25                      0.002                       0.000
# 25          D26                      0.001                       0.000
# 26          D27                      0.015                       0.001
# 27          D28                      0.004                       0.001
# 28          D29                      0.006                       0.001
# 29          D30                      0.004                       0.001
# 30          D32                      0.002                       0.000
# 31          D34                      0.003                       0.001
# 32          D99                      0.013                       0.004
#
#     is novel binary sub: D-D  multiple novelty sub: D-D  \
# 0                      0.640                      0.464
# 1                      0.288                      0.177
# 2                      0.456                      0.309
# 3                      0.316                      0.180
# 4                      0.516                      0.361
# 5                      0.387                      0.251
# 6                      0.414                      0.286
# 7                      0.312                      0.172
# 8                      0.499                      0.357
# 9                      0.290                      0.167
# 10                     0.450                      0.304
# 11                     0.216                      0.113
# 12                     0.226                      0.118
# 13                     0.292                      0.189
# 14                     0.254                      0.133
# 15                     0.246                      0.151
# 16                     0.270                      0.158
# 17                     0.250                      0.146
# 18                     0.544                      0.399
# 19                     0.498                      0.309
# 20                     0.419                      0.250
# 21                     0.209                      0.094
# 22                     0.250                      0.138
# 23                     0.316                      0.182
# 24                     0.250                      0.133
# 25                     0.256                      0.147
# 26                     0.529                      0.363
# 27                     0.347                      0.228
# 28                     0.337                      0.187
# 29                     0.537                      0.357
# 30                     0.271                      0.161
# 31                     0.323                      0.179
# 32                     0.537                      0.363
#
#     is novel binary main: D-U  multiple novelty main: D-U  \
# 0                       0.806                       0.494
# 1                       0.575                       0.289
# 2                       0.774                       0.459
# 3                       0.663                       0.400
# 4                       0.818                       0.543
# 5                       0.741                       0.327
# 6                       0.706                       0.380
# 7                       0.710                       0.473
# 8                       0.763                       0.427
# 9                       0.740                       0.367
# 10                      0.706                       0.317
# 11                      0.687                       0.229
# 12                      0.634                       0.395
# 13                      0.607                       0.288
# 14                      0.753                       0.477
# 15                      0.538                       0.320
# 16                      0.547                       0.333
# 17                      0.605                       0.268
# 18                      0.788                       0.465
# 19                      0.836                       0.534
# 20                      0.685                       0.414
# 21                      0.541                       0.333
# 22                      0.744                       0.340
# 23                      0.651                       0.467
# 24                      0.729                       0.499
# 25                      0.710                       0.243
# 26                      0.762                       0.372
# 27                      0.644                       0.337
# 28                      0.646                       0.447
# 29                      0.708                       0.551
# 30                      0.664                       0.382
# 31                      0.721                       0.498
# 32                      0.735                       0.436
#
#     is novel binary sub: D-U  multiple novelty sub: D-U  \
# 0                      0.806                      0.494
# 1                      0.575                      0.289
# 2                      0.774                      0.459
# 3                      0.663                      0.400
# 4                      0.818                      0.543
# 5                      0.741                      0.327
# 6                      0.706                      0.380
# 7                      0.710                      0.473
# 8                      0.763                      0.427
# 9                      0.740                      0.367
# 10                     0.706                      0.317
# 11                     0.687                      0.229
# 12                     0.634                      0.395
# 13                     0.607                      0.288
# 14                     0.753                      0.477
# 15                     0.538                      0.320
# 16                     0.547                      0.333
# 17                     0.605                      0.268
# 18                     0.788                      0.465
# 19                     0.836                      0.534
# 20                     0.685                      0.414
# 21                     0.541                      0.333
# 22                     0.744                      0.340
# 23                     0.651                      0.467
# 24                     0.729                      0.499
# 25                     0.710                      0.243
# 26                     0.762                      0.372
# 27                     0.644                      0.337
# 28                     0.646                      0.447
# 29                     0.708                      0.551
# 30                     0.664                      0.382
# 31                     0.721                      0.498
# 32                     0.735                      0.436
#
#     max novelty main: D-D  max novelty sub: D-D  max novelty main: D-U  \
# 0                   0.506                -2.838                 -4.785
# 1                  -0.895                -2.476                 -4.426
# 2                   0.871                -2.420                 -3.880
# 3                  -0.728                -3.260                 -4.247
# 4                   0.018                -2.961                 -3.922
# 5                   0.620                -2.961                 -4.738
# 6                   0.655                -2.539                 -4.115
# 7                   0.653                -3.101                 -4.505
# 8                   0.754                -0.651                 -2.995
# 9                   0.241                -3.221                 -5.214
# 10                  0.476                -3.253                 -5.328
# 11                 -0.511                -4.622                 -5.813
# 12                  0.228                -2.851                 -4.219
# 13                  0.550                -1.972                 -3.619
# 14                 -0.191                -4.292                 -5.242
# 15                 -0.935                -3.306                 -4.912
# 16                 -1.549                -4.667                 -6.299
# 17                 -0.218                -3.631                 -5.647
# 18                  0.980                -1.911                 -4.304
# 19                  1.033                -2.726                 -4.277
# 20                  0.419                -4.658                 -5.604
# 21                 -1.145                -5.135                 -5.847
# 22                  0.032                -3.845                 -4.932
# 23                  0.606                -3.167                 -4.310
# 24                 -0.899                -4.600                 -4.851
# 25                 -0.385                -3.273                 -3.969
# 26                 -0.440                -4.009                 -5.755
# 27                  0.231                -3.846                 -5.399
# 28                 -0.223                -4.404                 -4.826
# 29                  0.935                -2.816                 -4.727
# 30                 -0.270                -4.110                 -4.888
# 31                  0.179                -3.377                 -4.353
# 32                  0.885                -3.319                 -5.331
#
#     max novelty sub: D-U                                         class name
# 0                 -4.785                                    Edible Products
# 1                 -4.426                           Apparel and Haberdashery
# 2                 -3.880  Travel Goods, Personal Belongings, and Storage...
# 3                 -4.247                                          Brushware
# 4                 -3.922        Textile or Paper Yard Goods; Sheet Material
# 5                 -4.738                                        Furnishings
# 6                 -4.115  Equipment for Preparing or Serving Food or Dri...
# 7                 -4.505                                 Tools and Hardware
# 8                 -2.995                  Packages and Containers for Goods
# 9                 -5.214        Measuring, Testing or Signaling Instruments
# 10                -5.328          Jewelry, Symbolic Insignia, and Ornaments
# 11                -5.813                                     Transportation
# 12                -4.219  Equipment for Production, Distribution, or Tra...
# 13                -3.619  Recording, Communication, or Information Retri...
# 14                -5.242                   Machines Not Elsewhere Specified
# 15                -4.912                  Photography and Optical Equipment
# 16                -6.299                                Musical Instruments
# 17                -5.647                      Printing and Office Machinery
# 18                -4.304  Office Supplies; Artists' and Teachers' Materials
# 19                -4.277                    Sales and Advertising Equipment
# 20                -5.604                       Games, Toys and Sports Goods
# 21                -5.847  Arms, Pyrotechnics, Hunting and Fishing Equipment
# 22                -4.932  Environmental Heating and Cooling, Fluid Handl...
# 23                -4.310                   Medical and Laboratory Equipment
# 24                -4.851           Building Units and Construction Elements
# 25                -3.969                                           Lighting
# 26                -5.755                      Tobacco and Smokers' Supplies
# 27                -5.399              Cosmetic Products and Toilet Articles
# 28                -4.826        Equipment for Safety, Protection and Rescue
# 29                -4.727                                   Animal Husbandry
# 30                -4.888               Washing, Cleaning or Drying Machines
# 31                -4.353             Material or Article Handling Equipment
# 32                -5.331                                      Miscellaneous

# %%
#save this table
table.to_csv('data/table.csv')

# %%
#correlation
table.corr().round(3)
# Out:
#                             is novel binary main: D-D  \
# is novel binary main: D-D                       1.000
# multiple novelty main: D-D                      0.707
# is novel binary sub: D-D                        0.476
# multiple novelty sub: D-D                       0.463
# is novel binary main: D-U                       0.134
# multiple novelty main: D-U                      0.218
# is novel binary sub: D-U                        0.134
# multiple novelty sub: D-U                       0.218
# max novelty main: D-D                          -0.129
# max novelty sub: D-D                           -0.148
# max novelty main: D-U                          -0.333
# max novelty sub: D-U                           -0.333
#
#                             multiple novelty main: D-D  \
# is novel binary main: D-D                        0.707
# multiple novelty main: D-D                       1.000
# is novel binary sub: D-D                         0.568
# multiple novelty sub: D-D                        0.545
# is novel binary main: D-U                        0.241
# multiple novelty main: D-U                       0.406
# is novel binary sub: D-U                         0.241
# multiple novelty sub: D-U                        0.406
# max novelty main: D-D                            0.326
# max novelty sub: D-D                             0.102
# max novelty main: D-U                           -0.071
# max novelty sub: D-U                            -0.071
#
#                             is novel binary sub: D-D  \
# is novel binary main: D-D                      0.476
# multiple novelty main: D-D                     0.568
# is novel binary sub: D-D                       1.000
# multiple novelty sub: D-D                      0.991
# is novel binary main: D-U                      0.664
# multiple novelty main: D-U                     0.545
# is novel binary sub: D-U                       0.664
# multiple novelty sub: D-U                      0.545
# max novelty main: D-D                          0.629
# max novelty sub: D-D                           0.473
# max novelty main: D-U                          0.231
# max novelty sub: D-U                           0.231
#
#                             multiple novelty sub: D-D  \
# is novel binary main: D-D                       0.463
# multiple novelty main: D-D                      0.545
# is novel binary sub: D-D                        0.991
# multiple novelty sub: D-D                       1.000
# is novel binary main: D-U                       0.639
# multiple novelty main: D-U                      0.481
# is novel binary sub: D-U                        0.639
# multiple novelty sub: D-U                       0.481
# max novelty main: D-D                           0.613
# max novelty sub: D-D                            0.523
# max novelty main: D-U                           0.256
# max novelty sub: D-U                            0.256
#
#                             is novel binary main: D-U  \
# is novel binary main: D-D                       0.134
# multiple novelty main: D-D                      0.241
# is novel binary sub: D-D                        0.664
# multiple novelty sub: D-D                       0.639
# is novel binary main: D-U                       1.000
# multiple novelty main: D-U                      0.578
# is novel binary sub: D-U                        1.000
# multiple novelty sub: D-U                       0.578
# max novelty main: D-D                           0.620
# max novelty sub: D-D                            0.339
# max novelty main: D-U                           0.338
# max novelty sub: D-U                            0.338
#
#                             multiple novelty main: D-U  \
# is novel binary main: D-D                        0.218
# multiple novelty main: D-D                       0.406
# is novel binary sub: D-D                         0.545
# multiple novelty sub: D-D                        0.481
# is novel binary main: D-U                        0.578
# multiple novelty main: D-U                       1.000
# is novel binary sub: D-U                         0.578
# multiple novelty sub: D-U                        1.000
# max novelty main: D-D                            0.444
# max novelty sub: D-D                             0.181
# max novelty main: D-U                            0.310
# max novelty sub: D-U                             0.310
#
#                             is novel binary sub: D-U  \
# is novel binary main: D-D                      0.134
# multiple novelty main: D-D                     0.241
# is novel binary sub: D-D                       0.664
# multiple novelty sub: D-D                      0.639
# is novel binary main: D-U                      1.000
# multiple novelty main: D-U                     0.578
# is novel binary sub: D-U                       1.000
# multiple novelty sub: D-U                      0.578
# max novelty main: D-D                          0.620
# max novelty sub: D-D                           0.339
# max novelty main: D-U                          0.338
# max novelty sub: D-U                           0.338
#
#                             multiple novelty sub: D-U  max novelty main: D-D  \
# is novel binary main: D-D                       0.218                 -0.129
# multiple novelty main: D-D                      0.406                  0.326
# is novel binary sub: D-D                        0.545                  0.629
# multiple novelty sub: D-D                       0.481                  0.613
# is novel binary main: D-U                       0.578                  0.620
# multiple novelty main: D-U                      1.000                  0.444
# is novel binary sub: D-U                        0.578                  0.620
# multiple novelty sub: D-U                       1.000                  0.444
# max novelty main: D-D                           0.444                  1.000
# max novelty sub: D-D                            0.181                  0.620
# max novelty main: D-U                           0.310                  0.470
# max novelty sub: D-U                            0.310                  0.470
#
#                             max novelty sub: D-D  max novelty main: D-U  \
# is novel binary main: D-D                 -0.148                 -0.333
# multiple novelty main: D-D                 0.102                 -0.071
# is novel binary sub: D-D                   0.473                  0.231
# multiple novelty sub: D-D                  0.523                  0.256
# is novel binary main: D-U                  0.339                  0.338
# multiple novelty main: D-U                 0.181                  0.310
# is novel binary sub: D-U                   0.339                  0.338
# multiple novelty sub: D-U                  0.181                  0.310
# max novelty main: D-D                      0.620                  0.470
# max novelty sub: D-D                       1.000                  0.816
# max novelty main: D-U                      0.816                  1.000
# max novelty sub: D-U                       0.816                  1.000
#
#                             max novelty sub: D-U
# is novel binary main: D-D                 -0.333
# multiple novelty main: D-D                -0.071
# is novel binary sub: D-D                   0.231
# multiple novelty sub: D-D                  0.256
# is novel binary main: D-U                  0.338
# multiple novelty main: D-U                 0.310
# is novel binary sub: D-U                   0.338
# multiple novelty sub: D-U                  0.310
# max novelty main: D-D                      0.470
# max novelty sub: D-D                       0.816
# max novelty main: D-U                      1.000
# max novelty sub: D-U                       1.000

# %%
#Save the correlation table
table.corr().round(3).to_csv('data/corr_table.csv')

# %% [markdown]
# Below are a bit of descriptive stats for the above measures

# %%
master['is novel binary main: D-D'].value_counts()
# Out:
# 0.0    474238
# 1.0      1026
# Name: is novel binary main: D-D, dtype: int64

# %%
master['is novel binary sub: D-D'].value_counts()
# Out:
# 0.0    317256
# 1.0    158008
# Name: is novel binary sub: D-D, dtype: int64

# %%
master['is novel binary main: D-U'].value_counts()
# Out:
# 1.0    212074
# 0.0     96649
# Name: is novel binary main: D-U, dtype: int64

# %%
master['is novel binary sub: D-U'].value_counts()
# Out:
# 1.0    212074
# 0.0     96649
# Name: is novel binary sub: D-U, dtype: int64

# %%
master['max novelty main: D-D'].describe()
# Out:
# count    475264.000000
# mean          0.222976
# std           1.688454
# min          -5.216022
# 25%          -1.211405
# 50%          -0.368211
# 75%           1.747975
# max           5.728431
# Name: max novelty main: D-D, dtype: float64

# %%
master['max novelty sub: D-D'].describe()
# Out:
# count    475264.000000
# mean         -3.075206
# std           2.098393
# min         -11.636991
# 25%          -4.541145
# 50%          -3.012485
# 75%          -1.555243
# max           4.032047
# Name: max novelty sub: D-D, dtype: float64

# %%
master['max novelty main: D-U'].describe()
# Out:
# count    308723.000000
# mean         -4.541657
# std           1.839085
# min         -13.114638
# 25%          -5.715160
# 50%          -4.442751
# 75%          -3.245814
# max           2.409061
# Name: max novelty main: D-U, dtype: float64

# %%
master['max novelty sub: D-U'].describe()
# Out:
# count    308723.000000
# mean         -4.541657
# std           1.839085
# min         -13.114638
# 25%          -5.715160
# 50%          -4.442751
# 75%          -3.245814
# max           2.409061
# Name: max novelty sub: D-U, dtype: float64
