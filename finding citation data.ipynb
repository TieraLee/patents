# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import grequests
import json
import asyncio
import concurrent.futures
import random
import asyncio
from aiohttp import ClientSession
import os
import aiohttp

# %%
# debugging ascyncio

os.environ['PYTHONASYNCIODEBUG'] = '1'

# %% [markdown]
# # Note 1
# If the citation data is not local avaiable on your machine, run the following code blocks. Otherwise this can be skipped until note 2

# %%
master = pd.read_csv('designDirty.csv', usecols=['applications','cited_patents','patent_number','uspcs'])
master.head()

# %%
#clean data
def remove_non_design(df):
    #filter to make sure mis-classified patents are not included
    return df[df.patent_number.str.contains('D')]

# %%
master = remove_non_design(master)

# %%
master.shape

# %%
def extract_date(df):
    keep = df.copy()
    #extract application date and year
    keep['app_date'] = keep['applications'].astype(str).str.extract('(\d{4}-\d{2}-\d{2})')
#     set_trace()
    pd.to_datetime(keep.app_date, errors='coerce')
    keep.drop('applications', axis=1, inplace=True)
    
    keep['app_date'] = pd.to_datetime(keep['app_date'], errors='coerce')
    keep['year'] =keep['app_date'].apply(lambda x: x.year)
    return keep

# %%
des = extract_date(master)

# %%
des = des[['patent_number','year','uspcs']]
des.head()

# %%
def extract_class(df):
    keep = df.copy()
    #extract class information
    pattern = "([D0-9]\d{2}/\d{1,3}\.?\d{1,2})"

    keep['uspcs'] = keep['uspcs'].astype(str).str.findall(pattern)
    holder = keep.apply(lambda x: pd.Series(x['uspcs']),axis=1).stack().reset_index(level=1, drop=True)
    holder.name = 'class'
    return keep.drop('uspcs', axis=1).join(holder)

# %%
des = extract_class(des)

# %%
des.isnull().sum()

# %%
des[des['class'].isnull()]

# %%
#remove the patents without a class because they are useless for our anaysis
# figure out why they are null
master[master.patent_number == 'D806240']

# %%
des = des.dropna().reset_index()

# %%
des.shape

# %%
# number of unique patent numbers represented
des.patent_number.nunique()

# %%
des.to_csv('designYearClass.csv')

# %%
#creating data frame just for citations
des_citations = master[master.patent_number.isin(des.drop_duplicates(subset=['patent_number']).patent_number)]

#checking for the same number of patents represented
des_citations.shape

# %%
afiliatedes_citations = des_citations[['patent_number','cited_patents']].reset_index(drop=True)

# %%
des_citations.tail()

# %%
def extract_citation(df):
    keep = df.copy()
    #extract class information
    pattern = "(\d{7}|D\d{6})"

    keep['cited_patents'] = keep['cited_patents'].astype(str).str.findall(pattern)
    holder = keep.apply(lambda x: pd.Series(x['cited_patents']),axis=1).stack().reset_index(level=1, drop=True)
    holder.name = 'reference'
    return keep.drop('cited_patents', axis=1).join(holder)

# %%
# because of how much citations explode, the extraction of citations must be done iterativly and combined for the final dataframe
citations = pd.DataFrame()

for i in range(0,des_citations.shape[0],50):
    print(i)
    if (des_citations.shape[0] - i < 50):
        temp = extract_citation(des_citations.loc[i:])
    else:
        temp = extract_citation(des_citations.iloc[i:i+50])
    
    citations = pd.concat([citations, temp], ignore_index=True)

# %%
citations.sample(50)

# %%
citations.shape

# %%
citations.dropna(subset=['reference'], inplace=True)

# %%
citations.shape

# %%
citations.groupby('patent_number').agg('count').describe()

# %%
citations.to_csv('designCitations.csv')

# %% [markdown]
# # Note 2
# If the citation data is available locally on your machine, just run the following code blocks, including the commented out immediatly after this. Be sure to run the first code block for the imports

# %%
citations = pd.read_csv('designCitations.csv', usecols=['patent_number','reference'])

# %%
# Just design citations
citations_design = citations[citations.reference.str.contains('D')].reset_index(drop=True)
citations_design.groupby('patent_number').agg('count').describe()
# Out:
#            reference
# count  461903.000000
# mean        9.413589
# std        14.965143
# min         1.000000
# 25%         3.000000
# 50%         6.000000
# 75%        11.000000
# max       561.000000

# %%
# just utility citations
citations_utility = citations[~citations.reference.str.contains('D')].reset_index(drop=True)
citations_utility.groupby('patent_number').agg('count').describe()
# Out:
#            reference
# count  301536.000000
# mean        6.246083
# std        16.454657
# min         1.000000
# 25%         1.000000
# 50%         3.000000
# 75%         6.000000
# max       988.000000

# %%
# ## Now pull citation
# def pull_citation_classes(starter_df, reference_df):
#     base_url = "http://www.patentsview.org/api/patents/query?"
#     field_list = "&f=[\"patent_number\",\"uspc_subclass_id\"]"

#     for i, value in reference_df.reference.iteritems():
#         query = "q={{\"patent_number\":\"{}\"}}".format(value)
#         full_url = base_url + query + field_list
#     #     print(full_url)
#         r = requests.get(full_url)
#         print(i)
#         print(r)
#         data = r.json()
#         df = pd.io.json.json_normalize(data['patents'])
#         starter_df = pd.concat([starter_df, df], ignore_index=True)
#     return starter_df

# %%
# citations_design_class = pd.DataFrame()
# citations_design_class = pull_citation_classes(citations_design_class, citations_design)

# %%
def gather_urls(series):
    urls = []
    base_url = "http://www.patentsview.org/api/patents/query?"
    field_list = "&f=[\"patent_number\",\"uspc_subclass_id\"]"
    for i, value in series.iteritems():
        query = "q={{\"patent_number\":\"{}\"}}".format(value)
        urls.append(base_url + query + field_list)
    return urls

# %%
# def urls_to_dataframe(urls, size=100):
#     results = grequests.map((grequests.get(u) for u in urls), size=size)
#     starter_df = pd.DataFrame()
#     for r in results:
#         data = r.json()
#         df = pd.io.json.json_normalize(data['patents'])
#         starter_df = pd.concat([starter_df, df], ignore_index=True)
#     return starter_df

# %%
utility_urls = gather_urls(citations_utility.reference)

len(utility_urls)
# Out:
# 1883419

# %%
util_mini = utility_urls[:1000]

# %%
sucessful_responses = []
unsucessful_responses = []## Bad coding practice! creates a weird coupling, will fix later (maybe)

# %%
async def fetch(url, session):
    async with session.get(url) as response:
        print(response.status)
        if(response.status == 503):
            print('this is where I died')
#             sucessful_responses.append(await response.json())
#         else:
#             response.release()
        


async def bound_fetch(sem, url, session):
    # Getter function with semaphore.
    async with sem:
        await fetch(url, session)


async def run(r):
    tasks = []
    # create instance of Semaphore
    sem = asyncio.Semaphore(1000)

    # Create client session that will ensure we dont open new connection
    # per each request.
    async with ClientSession() as session:
        for i in range(r):
            # pass Semaphore and session to every GET request
            task = asyncio.ensure_future(bound_fetch(sem, util_mini[i], session))
            tasks.append(task)

        responses = asyncio.wait(*tasks)
        await responses
        
number = 1000
loop = asyncio.get_event_loop()

future = asyncio.ensure_future(run(number))
loop.run_until_complete(future)
# Out:
# Executing <Task pending coro=<run() running at <ipython-input-41-347a7b8bf17e>:32> wait_for=<_GatheringFuture pending cb=[<TaskWakeupMethWrapper object at 0x7f8bea9f8df8>()] created at /home/tiera/anaconda3/lib/python3.6/asyncio/tasks.py:549> cb=[_run_until_complete_cb() at /home/tiera/anaconda3/lib/python3.6/asyncio/base_events.py:176] created at <ipython-input-41-347a7b8bf17e>:37> took 0.285 seconds
# Executing <Task pending coro=<bound_fetch() running at <ipython-input-41-347a7b8bf17e>:15> wait_for=<Future pending cb=[<TaskWakeupMethWrapper object at 0x7f8bf44117c8>()] created at /home/tiera/anaconda3/lib/python3.6/asyncio/base_events.py:275> cb=[gather.<locals>._done_callback(214)() at /home/tiera/anaconda3/lib/python3.6/asyncio/tasks.py:616] created at <ipython-input-41-347a7b8bf17e>:28> took 0.430 seconds
# Executing <Handle <TaskWakeupMethWrapper object at 0x7f8be91fabb8>(<Future finis...events.py:275>) created at /home/tiera/anaconda3/lib/python3.6/asyncio/locks.py:431> took 0.471 seconds
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 503
# this is where I died
# 503
# this is where I died
# 503
# this is where I died
# 503
# this is where I died
# 503
# this is where I died
# 503
# this is where I died
# 503
# this is where I died
# 503
# this is where I died
# 503
# this is where I died
# 503
# this is where I died
# 503
# this is where I died
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# <ipython-input-41-347a7b8bf17e> in <module>()
#      36
#      37 future = asyncio.ensure_future(run(number))
# ---> 38 loop.run_until_complete(future)
#
# ~/anaconda3/lib/python3.6/asyncio/base_events.py in run_until_complete(self, future)
#     465             raise RuntimeError('Event loop stopped before Future completed.')
#     466
# --> 467         return future.result()
#     468
#     469     def stop(self):
#
# CancelledError:

# %%
dir(aiohttp.ClientResponse)
# Out:
# ['ATTRS',
#  '__aenter__',
#  '__aexit__',
#  '__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_cleanup_writer',
#  '_closed',
#  '_connection',
#  '_content_dict',
#  '_content_type',
#  '_headers',
#  '_notify_content',
#  '_parse_content_type',
#  '_reader',
#  '_response_eof',
#  '_source_traceback',
#  '_stored_content_type',
#  'charset',
#  'close',
#  'closed',
#  'connection',
#  'content',
#  'content_disposition',
#  'content_length',
#  'content_type',
#  'get_encoding',
#  'headers',
#  'history',
#  'host',
#  'json',
#  'raise_for_status',
#  'raw_headers',
#  'read',
#  'reason',
#  'release',
#  'request_info',
#  'start',
#  'status',
#  'text',
#  'url',
#  'url_obj',
#  'version',
#  'wait_for_close']

# %%
starter_df = pd.DataFrame()
for r in results:
    data = r.json()
    df = pd.io.json.json_normalize(data['patents'])
    starter_df = pd.concat([starter_df, df], ignore_index=True)

# %%
starter_df

# %%
len(sucessful_responses)
# Out:
# 3017

# %%
len(unsucessful_responses)
# Out:
# 1

# %%
sucessful_responses
# Out:
# [{'count': 1,
#   'patents': [{'patent_number': '3939620',
#     'uspcs': [{'uspc_subclass_id': '52/717.5'},
#      {'uspc_subclass_id': '52/476'},
#      {'uspc_subclass_id': '52/775'},
#      {'uspc_subclass_id': '52/781'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4021980',
#     'uspcs': [{'uspc_subclass_id': '40/732'},
#      {'uspc_subclass_id': '49/61'},
#      {'uspc_subclass_id': '52/202'},
#      {'uspc_subclass_id': '52/476'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4069641',
#     'uspcs': [{'uspc_subclass_id': '52/202'},
#      {'uspc_subclass_id': '52/476'},
#      {'uspc_subclass_id': '52/717.1'},
#      {'uspc_subclass_id': 'D25/48.7'},
#      {'uspc_subclass_id': 'D25/119'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '3935984',
#     'uspcs': [{'uspc_subclass_id': '600/499'},
#      {'uspc_subclass_id': 'D24/165'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '3992809',
#     'uspcs': [{'uspc_subclass_id': '47/62R'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '
}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4165550',
#     'uspcs': [{'uspc_subclass_id': '15/144.2'},
#      {'uspc_subclass_id': '15/145'},
#      {'uspc_subclass_id': '15/229.8'},
#      {'uspc_subclass_id': '403/57'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4077198',
#     'uspcs': [{'uspc_subclass_id': '368/76'},
#      {'uspc_subclass_id': '368/223'},
#      {'uspc_subclass_id': '968/804'},
#      {'uspc_subclass_id': 'D10/1'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4210535',
#     'uspcs': [{'uspc_subclass_id': '210/222'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4213211',
#     'uspcs': [{'uspc_subclass_id': '4/239'},
#      {'uspc_subclass_id': '4/235'},
#      {'uspc_subclass_id': '4/240'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '3962763',
#     'uspcs': [{'uspc_subclass_id': '29/6.1'},
#      {'uspc_subclass_id': '52/635'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '3962763',
#     'uspcs': [{'uspc_subclass_id': '29/6.1'},
#      {'uspc_subclass_id': '52/635'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '3962763',
#     'uspcs': [{'uspc_subclass_id': '29/6.1'},
#      {'uspc_subclass_id': '52/635'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4013109',
#     'uspcs': [{'uspc_subclass_id': '206/370'},
#      {'uspc_subclass_id': '206/63.3'},
#      {'uspc_subclass_id': '206/350'},
#      {'uspc_subclass_id': '206/818'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4151913',
#     'uspcs': [{'uspc_subclass_id': '206/370'},
#      {'uspc_subclass_id': '206/63.3'},
#      {'uspc_subclass_id': '206/382'},
#      {'uspc_subclass_id': '206/495'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4126145',
#     'uspcs': [{'uspc_subclass_id': '132/288'},
#      {'uspc_subclass_id': '132/294'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '3934922',
#     'uspcs': [{'uspc_subclass_id': '105/1.1'},
#      {'uspc_subclass_id': '296/180.4'},
#      {'uspc_subclass_id': '296/91'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '3999797',
#     'uspcs': [{'uspc_subclass_id': '105/1.2'},
#      {'uspc_subclass_id': '244/130'},
#      {'uspc_subclass_id': '296/180.4'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '3997073',
#     'uspcs': [{'uspc_subclass_id': '206/557'},
#      {'uspc_subclass_id': '220/573'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4099598',
#     'uspcs': [{'uspc_subclass_id': '141/313'},
#      {'uspc_subclass_id': '141/340'},
#      {'uspc_subclass_id': '184/106'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '3965608',
#     'uspcs': [{'uspc_subclass_id': '124/65'},
#      {'uspc_subclass_id': '15/341'},
#      {'uspc_subclass_id': '15/344'},
#      {'uspc_subclass_id': '228/20.5'},
#      {'uspc_subclass_id': '43/110'},
#      {'uspc_subclass_id': '43/139'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4074458',
#     'uspcs': [{'uspc_subclass_id': '15/344'},
#      {'uspc_subclass_id': '43/139'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4175352',
#     'uspcs': [{'uspc_subclass_id': '15/342'},
#      {'uspc_subclass_id': '15/344'},
#      {'uspc_subclass_id': '15/346'},
#      {'uspc_subclass_id': '43/139'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4010989',
#     'uspcs': [{'uspc_subclass_id': '312/204'},
#      {'uspc_subclass_id': '312/215'},
#      {'uspc_subclass_id': '312/333'},
#      {'uspc_subclass_id': '70/85'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4184724',
#     'uspcs': [{'uspc_subclass_id': '220/212.5'},
#      {'uspc_subclass_id': '220/755'},
#      {'uspc_subclass_id': '220/758'},
#      {'uspc_subclass_id': '248/345.1'},
#      {'uspc_subclass_id': '312/209'},
#      {'uspc_subclass_id': '49/460'},
#      {'uspc_subclass_id': 'D06/661'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4255855',
#     'uspcs': [{'uspc_subclass_id': '30/120.5'},
#      {'uspc_subclass_id': '30/120.2'},
#      {'uspc_subclass_id': '99/572'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '3980319',
#     'uspcs': [{'uspc_subclass_id': '182/89'},
#      {'uspc_subclass_id': '182/91'},
#      {'uspc_subclass_id': '280/166'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '3980319',
#     'uspcs': [{'uspc_subclass_id': '182/89'},
#      {'uspc_subclass_id': '182/91'},
#      {'uspc_subclass_id': '280/166'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4196906',
#     'uspcs': [{'uspc_subclass_id': '369/262'},
#      {'uspc_subclass_id': '720/632'},
#      {'uspc_subclass_id': 'G9B/17.1'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4064374',
#     'uspcs': [{'uspc_subclass_id': '360/137'},
#      {'uspc_subclass_id': '369/11'},
#      {'uspc_subclass_id': '455/344'},
#      {'uspc_subclass_id': 'G9B/31.1'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4139298',
#     'uspcs': [{'uspc_subclass_id': '355/60'},
#      {'uspc_subclass_id': '399/200'},
#      {'uspc_subclass_id': '399/205'},
#      {'uspc_subclass_id': '399/208'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4247192',
#     'uspcs': [{'uspc_subclass_id': '355/23'},
#      {'uspc_subclass_id': '355/25'},
#      {'uspc_subclass_id': '355/46'},
#      {'uspc_subclass_id': '355/66'},
#      {'uspc_subclass_id': '399/203'},
#      {'uspc_subclass_id': '399/374'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4036500',
#     'uspcs': [{'uspc_subclass_id': '273/237'},
#      {'uspc_subclass_id': '273/248'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4103895',
#     'uspcs': [{'uspc_subclass_id': '273/441'},
#      {'uspc_subclass_id': '273/455'},
#      {'uspc_subclass_id': '273/DIG27'},
#      {'uspc_subclass_id': '463/15'},
#      {'uspc_subclass_id': '463/37'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4075771',
#     'uspcs': [{'uspc_subclass_id': '434/202'},
#      {'uspc_subclass_id': '446/143'},
#      {'uspc_subclass_id': 'D18/7'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4090593',
#     'uspcs': [{'uspc_subclass_id': '190/103'},
#      {'uspc_subclass_id': '190/111'},
#      {'uspc_subclass_id': '383/2'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4105121',
#     'uspcs': [{'uspc_subclass_id': '206/592'},
#      {'uspc_subclass_id': '206/459.5'},
#      {'uspc_subclass_id': '220/23.87'},
#      {'uspc_subclass_id': '220/784'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4179078',
#     'uspcs': [{'uspc_subclass_id': '242/597.4'},
#      {'uspc_subclass_id': '242/597.8'},
#      {'uspc_subclass_id': '312/34.22'},
#      {'uspc_subclass_id': '312/215'},
#      {'uspc_subclass_id': 'D06/523'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4113312',
#     'uspcs': [{'uspc_subclass_id': '297/452.63'},
#      {'uspc_subclass_id': '297/451.3'},
#      {'uspc_subclass_id': '297/452.19'},
#      {'uspc_subclass_id': 'D06/717'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '3953014',
#     'uspcs': [{'uspc_subclass_id': '249/91'},
#      {'uspc_subclass_id': '269/43'},
#      {'uspc_subclass_id': '269/254R'},
#      {'uspc_subclass_id': '269/909'},
#      {'uspc_subclass_id': 'D07/631'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4004501',
#     'uspcs': [{'uspc_subclass_id': '220/23.8'},
#      {'uspc_subclass_id': '99/426'},
#      {'uspc_subclass_id': 'D07/546'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4083453',
#     'uspcs': [{'uspc_subclass_id': '206/565'},
#      {'uspc_subclass_id': '206/564'},
#      {'uspc_subclass_id': 'D07/554.3'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4270660',
#     'uspcs': [{'uspc_subclass_id': '211/85.4'},
#      {'uspc_subclass_id': '99/420'},
#      {'uspc_subclass_id': 'D07/504'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '3986316',
#     'uspcs': [{'uspc_subclass_id': '211/189'},
#      {'uspc_subclass_id': '248/188.1'},
#      {'uspc_subclass_id': '403/218'},
#      {'uspc_subclass_id': '403/176'},
#      {'uspc_subclass_id': '403/231'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '3993005',
#     'uspcs': [{'uspc_subclass_id': '108/156'},
#      {'uspc_subclass_id': '248/188'},
#      {'uspc_subclass_id': '403/383'},
#      {'uspc_subclass_id': '403/384'},
#      {'uspc_subclass_id': 'D06/691.8'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4039133',
#     'uspcs': [{'uspc_subclass_id': '108/158.11'},
#      {'uspc_subclass_id': '211/182'},
#      {'uspc_subclass_id': '248/188.8'},
#      {'uspc_subclass_id': '403/176'},
#      {'uspc_subclass_id': '403/219'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '3993298',
#     'uspcs': [{'uspc_subclass_id': '269/91'},
#      {'uspc_subclass_id': '269/100'},
#      {'uspc_subclass_id': '269/254.CS'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4138111',
#     'uspcs': [{'uspc_subclass_id': '473/513'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4138111',
#     'uspcs': [{'uspc_subclass_id': '473/513'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '3955234',
#     'uspcs': [{'uspc_subclass_id': '15/236.6'},
#      {'uspc_subclass_id': '30/172'},
#      {'uspc_subclass_id': '452/104'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4003555',
#     'uspcs': [{'uspc_subclass_id': '220/568'},
#      {'uspc_subclass_id': '366/130'},
#      {'uspc_subclass_id': 'D07/300.1'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4103421',
#     'uspcs': [{'uspc_subclass_id': '30/162'},
#      {'uspc_subclass_id': '30/320'},
#      {'uspc_subclass_id': '30/335'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4233734',
#     'uspcs': [{'uspc_subclass_id': '30/162'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4240202',
#     'uspcs': [{'uspc_subclass_id': '30/162'},
#      {'uspc_subclass_id': '30/320'},
#      {'uspc_subclass_id': '30/331'},
#      {'uspc_subclass_id': '30/335'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4074550',
#     'uspcs': [{'uspc_subclass_id': '200/43.22'},
#      {'uspc_subclass_id': '200/61.54'},
#      {'uspc_subclass_id': '70/237'},
#      {'uspc_subclass_id': '70/18'},
#      {'uspc_subclass_id': '70/428'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4122318',
#     'uspcs': [{'uspc_subclass_id': '200/61.54'},
#      {'uspc_subclass_id': '340/465'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4129757',
#     'uspcs': [{'uspc_subclass_id': '200/4'},
#      {'uspc_subclass_id': '200/61.27'},
#      {'uspc_subclass_id': '200/61.54'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4277185',
#     'uspcs': [{'uspc_subclass_id': '366/213'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4115180',
#     'uspcs': [{'uspc_subclass_id': '156/446'},
#      {'uspc_subclass_id': '156/201'},
#      {'uspc_subclass_id': '156/468'},
#      {'uspc_subclass_id': '428/38'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4240867',
#     'uspcs': [{'uspc_subclass_id': '156/543'},
#      {'uspc_subclass_id': '156/199'},
#      {'uspc_subclass_id': '156/202'},
#      {'uspc_subclass_id': '156/216'},
#      {'uspc_subclass_id': '156/443'},
#      {'uspc_subclass_id': '156/446'},
#      {'uspc_subclass_id': '156/447'},
#      {'uspc_subclass_id': '156/448'},
#      {'uspc_subclass_id': '156/555'},
#      {'uspc_subclass_id': '156/577'},
#      {'uspc_subclass_id': '156/767'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4274904',
# ...
#     'uspcs': [{'uspc_subclass_id': '52/36.6'},
#      {'uspc_subclass_id': '52/239'},
#      {'uspc_subclass_id': '52/287.1'},
#      {'uspc_subclass_id': '52/656.1'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4121397',
#     'uspcs': [{'uspc_subclass_id': '52/286'},
#      {'uspc_subclass_id': '52/591.1'},
#      {'uspc_subclass_id': 'D25/113'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4101981',
#     'uspcs': [{'uspc_subclass_id': '2/182.6'},
#      {'uspc_subclass_id': '2/171.3'},
#      {'uspc_subclass_id': '2/195.2'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4133467',
#     'uspcs': [{'uspc_subclass_id': '211/70.2'},
#      {'uspc_subclass_id': '294/142'},
#      {'uspc_subclass_id': 'D03/259'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4154274',
#     'uspcs': [{'uspc_subclass_id': '206/315.2'},
#      {'uspc_subclass_id': '294/159'},
#      {'uspc_subclass_id': 'D03/259'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4047754',
#     'uspcs': [{'uspc_subclass_id': '297/158.3'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4071976',
#     'uspcs': [{'uspc_subclass_id': '248/312.1'},
#      {'uspc_subclass_id': '248/313'},
#      {'uspc_subclass_id': '47/39'},
#      {'uspc_subclass_id': '47/67'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4125300',
#     'uspcs': [{'uspc_subclass_id': '211/35'},
#      {'uspc_subclass_id': '211/70.5'},
#      {'uspc_subclass_id': '312/351'},
#      {'uspc_subclass_id': '312/324'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4100633',
#     'uspcs': [{'uspc_subclass_id': '135/90'},
#      {'uspc_subclass_id': '135/96'},
#      {'uspc_subclass_id': '135/115'},
#      {'uspc_subclass_id': '135/140'},
#      {'uspc_subclass_id': '135/155'},
#      {'uspc_subclass_id': '297/184.11'},
#      {'uspc_subclass_id': '428/12'},
#      {'uspc_subclass_id': '5/418'},
#      {'uspc_subclass_id': '5/639'},
#      {'uspc_subclass_id': '5/656'},
#      {'uspc_subclass_id': '5/904'},
#      {'uspc_subclass_id': '5/908'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '3942667',
#     'uspcs': [{'uspc_subclass_id': '215/12.1'},
#      {'uspc_subclass_id': '215/334'},
#      {'uspc_subclass_id': '217/6'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4163374',
#     'uspcs': [{'uspc_subclass_id': '220/592.1'},
#      {'uspc_subclass_id': '220/737'},
#      {'uspc_subclass_id': '220/903'},
#      {'uspc_subclass_id': '62/457.4'},
#      {'uspc_subclass_id': 'D07/608'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '3991596',
#     'uspcs': [{'uspc_subclass_id': '70/303A'},
#      {'uspc_subclass_id': '70/322'},
#      {'uspc_subclass_id': '70/355'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4149575',
#     'uspcs': [{'uspc_subclass_id': '141/98'},
#      {'uspc_subclass_id': '220/86.1'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4087650',
#     'uspcs': [{'uspc_subclass_id': '379/426'},
#      {'uspc_subclass_id': '379/434'},
#      {'uspc_subclass_id': '379/440'},
#      {'uspc_subclass_id': 'D14/143'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '3946543',
#     'uspcs': [{'uspc_subclass_id': '56/10.9'},
#      {'uspc_subclass_id': '56/11.9'},
#      {'uspc_subclass_id': '56/14.4'},
#      {'uspc_subclass_id': '56/16.9'},
#      {'uspc_subclass_id': '56/17.5'},
#      {'uspc_subclass_id': '56/17.6'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4312578',
#     'uspcs': [{'uspc_subclass_id': '353/79'},
#      {'uspc_subclass_id': '353/26R'},
#      {'uspc_subclass_id': '353/27R'},
#      {'uspc_subclass_id': '353/44'},
#      {'uspc_subclass_id': '353/119'},
#      {'uspc_subclass_id': 'D18/36'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4079394',
#     'uspcs': [{'uspc_subclass_id': '396/337'},
#      {'uspc_subclass_id': '396/544'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4107716',
#     'uspcs': [{'uspc_subclass_id': '396/545'},
#      {'uspc_subclass_id': '396/337'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4079394',
#     'uspcs': [{'uspc_subclass_id': '396/337'},
#      {'uspc_subclass_id': '396/544'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4107716',
#     'uspcs': [{'uspc_subclass_id': '396/545'},
#      {'uspc_subclass_id': '396/337'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4151988',
#     'uspcs': [{'uspc_subclass_id': '188/72.9'},
#      {'uspc_subclass_id': '482/54'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4200280',
#     'uspcs': [{'uspc_subclass_id': '403/327'},
#      {'uspc_subclass_id': '403/330'},
#      {'uspc_subclass_id': '482/98'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4236712',
#     'uspcs': [{'uspc_subclass_id': '482/98'},
#      {'uspc_subclass_id': '482/139'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4239216',
#     'uspcs': [{'uspc_subclass_id': '224/918'},
#      {'uspc_subclass_id': '473/285'},
#      {'uspc_subclass_id': '473/286'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4117624',
#     'uspcs': [{'uspc_subclass_id': '43/113'},
#      {'uspc_subclass_id': '43/114'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4127961',
#     'uspcs': [{'uspc_subclass_id': '43/139'},
#      {'uspc_subclass_id': '43/113'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4030664',
#     'uspcs': [{'uspc_subclass_id': '222/331'},
#      {'uspc_subclass_id': '222/385'},
#      {'uspc_subclass_id': '222/468'},
#      {'uspc_subclass_id': '222/481'},
#      {'uspc_subclass_id': '239/289'},
#      {'uspc_subclass_id': '239/333'},
#      {'uspc_subclass_id': '239/377'},
#      {'uspc_subclass_id': '239/443'},
#      {'uspc_subclass_id': 'D09/527'},
#      {'uspc_subclass_id': 'D23/212'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '3942647',
#     'uspcs': [{'uspc_subclass_id': '108/94'},
#      {'uspc_subclass_id': '211/144'},
#      {'uspc_subclass_id': '211/131.1'},
#      {'uspc_subclass_id': '211/163'},
#      {'uspc_subclass_id': '211/205'},
#      {'uspc_subclass_id': '312/125'},
#      {'uspc_subclass_id': 'D06/678.1'},
#      {'uspc_subclass_id': 'D06/680'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '3942647',
#     'uspcs': [{'uspc_subclass_id': '108/94'},
#      {'uspc_subclass_id': '211/144'},
#      {'uspc_subclass_id': '211/131.1'},
#      {'uspc_subclass_id': '211/163'},
#      {'uspc_subclass_id': '211/205'},
#      {'uspc_subclass_id': '312/125'},
#      {'uspc_subclass_id': 'D06/678.1'},
#      {'uspc_subclass_id': 'D06/680'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4114620',
#     'uspcs': [{'uspc_subclass_id': '5/421'},
#      {'uspc_subclass_id': '5/422'},
#      {'uspc_subclass_id': '607/104'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4149541',
#     'uspcs': [{'uspc_subclass_id': '5/421'},
#      {'uspc_subclass_id': '5/422'},
#      {'uspc_subclass_id': '607/104'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4197837',
#     'uspcs': [{'uspc_subclass_id': '137/565.27'},
#      {'uspc_subclass_id': '5/713'},
#      {'uspc_subclass_id': '5/714'},
#      {'uspc_subclass_id': '601/150'},
#      {'uspc_subclass_id': '601/149'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4225989',
#     'uspcs': [{'uspc_subclass_id': '5/713'},
#      {'uspc_subclass_id': '5/710'},
#      {'uspc_subclass_id': '5/714'},
#      {'uspc_subclass_id': '601/148'},
#      {'uspc_subclass_id': '601/158'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '3997966',
#     'uspcs': [{'uspc_subclass_id': '30/28'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4062109',
#     'uspcs': [{'uspc_subclass_id': '30/28'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4065904',
#     'uspcs': [{'uspc_subclass_id': '108/108'},
#      {'uspc_subclass_id': '211/193'},
#      {'uspc_subclass_id': '248/245'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4147122',
#     'uspcs': [{'uspc_subclass_id': '114/218'},
#      {'uspc_subclass_id': '114/112'},
#      {'uspc_subclass_id': '114/204'},
#      {'uspc_subclass_id': '24/115J'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4089543',
#     'uspcs': [{'uspc_subclass_id': '280/647'},
#      {'uspc_subclass_id': '280/650'},
#      {'uspc_subclass_id': '296/97.21'},
#      {'uspc_subclass_id': 'D12/128'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4266807',
#     'uspcs': [{'uspc_subclass_id': '280/650'},
#      {'uspc_subclass_id': '280/42'},
#      {'uspc_subclass_id': '280/642'},
#      {'uspc_subclass_id': '280/644'},
#      {'uspc_subclass_id': '280/649'},
#      {'uspc_subclass_id': '297/45'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4009885',
#     'uspcs': [{'uspc_subclass_id': '369/172'},
#      {'uspc_subclass_id': '369/136'},
#      {'uspc_subclass_id': '369/146'},
#      {'uspc_subclass_id': 'G9B/3.78'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4032725',
#     'uspcs': [{'uspc_subclass_id': '248/27.1'},
#      {'uspc_subclass_id': '381/395'},
#      {'uspc_subclass_id': '381/87'},
#      {'uspc_subclass_id': '381/386'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4277653',
#     'uspcs': [{'uspc_subclass_id': '181/150'},
#      {'uspc_subclass_id': '248/27.1'},
#      {'uspc_subclass_id': '381/395'},
#      {'uspc_subclass_id': '381/86'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4086981',
#     'uspcs': [{'uspc_subclass_id': '137/351'},
#      {'uspc_subclass_id': '184/1.5'},
#      {'uspc_subclass_id': '251/144'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '3954250',
#     'uspcs': [{'uspc_subclass_id': '137/351'},
#      {'uspc_subclass_id': '184/1.5'},
#      {'uspc_subclass_id': '251/144'},
#      {'uspc_subclass_id': '251/288'},
#      {'uspc_subclass_id': '251/294'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4019590',
#     'uspcs': [{'uspc_subclass_id': '175/57'},
#      {'uspc_subclass_id': '175/320'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4299382',
#     'uspcs': [{'uspc_subclass_id': '271/287'},
#      {'uspc_subclass_id': '271/258.1'},
#      {'uspc_subclass_id': '271/273'},
#      {'uspc_subclass_id': '271/297'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4095244',
#     'uspcs': [{'uspc_subclass_id': '352/243'},
#      {'uspc_subclass_id': '396/425'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4134324',
#     'uspcs': [{'uspc_subclass_id': '181/191'},
#      {'uspc_subclass_id': '84/411R'},
#      {'uspc_subclass_id': '984/151'},
#      {'uspc_subclass_id': 'D17/22'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4091918',
#     'uspcs': [{'uspc_subclass_id': '206/755'},
#      {'uspc_subclass_id': '206/425'},
#      {'uspc_subclass_id': '206/804'},
#      {'uspc_subclass_id': '312/271'},
#      {'uspc_subclass_id': '312/294'},
#      {'uspc_subclass_id': '40/388'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4291685',
#     'uspcs': [{'uspc_subclass_id': '219/227'},
#      {'uspc_subclass_id': '219/230'},
#      {'uspc_subclass_id': '601/17'},
#      {'uspc_subclass_id': '601/80'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4014133',
#     'uspcs': [{'uspc_subclass_id': '49/40'},
#      {'uspc_subclass_id': '49/197'},
#      {'uspc_subclass_id': '52/66'},
#      {'uspc_subclass_id': 'D25/15'},
#      {'uspc_subclass_id': 'D25/30'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '3966076',
#     'uspcs': [{'uspc_subclass_id': '206/5.1'},
#      {'uspc_subclass_id': '206/235'},
#      {'uspc_subclass_id': '220/520'},
#      {'uspc_subclass_id': '220/4.23'},
#      {'uspc_subclass_id': '220/771'},
#      {'uspc_subclass_id': '220/835'},
#      {'uspc_subclass_id': 'D03/264'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4079880',
#     'uspcs': [{'uspc_subclass_id': '220/4.21'},
#      {'uspc_subclass_id': '220/4.23'},
#      {'uspc_subclass_id': '220/4.24'},
#      {'uspc_subclass_id': '220/315'},
#      {'uspc_subclass_id': '220/835'},
#      {'uspc_subclass_id': '229/406'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4193150',
#     'uspcs': [{'uspc_subclass_id': '297/DIG1'},
#      {'uspc_subclass_id': '5/632'},
#      {'uspc_subclass_id': '5/633'},
#      {'uspc_subclass_id': '5/655.9'},
#      {'uspc_subclass_id': '5/924'},
#      {'uspc_subclass_id': 'D06/601'},
#      {'uspc_subclass_id': 'D06/606'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4214326',
#     'uspcs': [{'uspc_subclass_id': '5/632'},
#      {'uspc_subclass_id': '5/424'},
#      {'uspc_subclass_id': 'D24/183'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4190959',
#     'uspcs': [{'uspc_subclass_id': '33/3B'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4294014',
#     'uspcs': [{'uspc_subclass_id': '33/3C'}, {'uspc_subclass_id': '33/3B'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '3980410',
#     'uspcs': [{'uspc_subclass_id': '404/16'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4133261',
#     'uspcs': [{'uspc_subclass_id': '100/280'},
#      {'uspc_subclass_id': '100/295'},
#      {'uspc_subclass_id': '100/902'},
#      {'uspc_subclass_id': 'D15/123'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4143595',
#     'uspcs': [{'uspc_subclass_id': '100/280'},
#      {'uspc_subclass_id': '100/902'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4168661',
#     'uspcs': [{'uspc_subclass_id': '100/218'},
#      {'uspc_subclass_id': '100/245'},
#      {'uspc_subclass_id': '100/289'},
#      {'uspc_subclass_id': '100/293'},
#      {'uspc_subclass_id': '100/902'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4290354',
#     'uspcs': [{'uspc_subclass_id': '100/218'},
#      {'uspc_subclass_id': '100/266'},
#      {'uspc_subclass_id': '100/283'},
#      {'uspc_subclass_id': '100/293'},
#      {'uspc_subclass_id': '100/295'},
#      {'uspc_subclass_id': '100/902'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4051781',
#     'uspcs': [{'uspc_subclass_id': '101/348'},
#      {'uspc_subclass_id': '101/103'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4233694',
#     'uspcs': [{'uspc_subclass_id': '210/167.12'},
#      {'uspc_subclass_id': '335/207'},
#      {'uspc_subclass_id': '392/471'},
#      {'uspc_subclass_id': '4/541.3'},
#      {'uspc_subclass_id': '4/493'},
#      {'uspc_subclass_id': '4/509'},
#      {'uspc_subclass_id': '4/512'},
#      {'uspc_subclass_id': '4/541.2'},
#      {'uspc_subclass_id': '4/546'},
#      {'uspc_subclass_id': '4/590'}]}],
#   'total_patent_count': 1},
#  {'count': 1,
#   'patents': [{'patent_number': '4118946',
#     'uspcs': [{'uspc_subclass_id': '126/204'},
#      {'uspc_subclass_id': '165/46'},
#      {'uspc_subclass_id': '165/DIG45'},
#      {'uspc_subclass_id': '607/104'},
#      {'uspc_subclass_id': '62/384'},
#      {'uspc_subclass_id': '62/515'}]}],
#   'total_patent_count': 1}]
